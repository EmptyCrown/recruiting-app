# %%
import pandas as pd
import numpy as np
import json
import urllib
from collections import OrderedDict
import urllib.request as request
import requests
from collections import Counter
import random
import string

# %%
f = pd.read_csv('fortune500/fortune500.csv').rename(columns={'company':'name'})
f = f.set_index('name')
data = f.transpose().to_dict()

# %%
with open('fortune500.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
data
# Out:
# {0: {'city': 'Bentonville',
#   'industry': 'General Merchandisers',
#   'lat': 36.3729,
#   'location': 'Bentonville, AR',
#   'lon': -94.2088,
#   'name': 'Walmart',
#   'state': 'AR'},
#  1: {'city': 'Irving',
#   'industry': 'Petroleum Refining',
#   'lat': 32.814,
#   'location': 'Irving, TX',
#   'lon': -96.9489,
#   'name': 'Exxon Mobil',
#   'state': 'TX'},
#  2: {'city': 'San Ramon',
#   'industry': 'Petroleum Refining',
#   'lat': 37.7799,
#   'location': 'San Ramon, CA',
#   'lon': -121.978,
#   'name': 'Chevron',
#   'state': 'CA'},
#  3: {'city': 'Omaha',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 41.2524,
#   'location': 'Omaha, NE',
#   'lon': -95.99799999999999,
#   'name': 'Berkshire Hathaway',
#   'state': 'NE'},
#  4: {'city': 'Cupertino',
#   'industry': 'Computers, Office Equipment',
#   'lat': 37.323,
#   'location': 'Cupertino, CA',
#   'lon': -122.03200000000001,
#   'name': 'Apple',
#   'state': 'CA'},
#  5: {'city': 'Detroit',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 42.3314,
#   'location': 'Detroit, MI',
#   'lon': -83.0458,
#   'name': 'General Motors',
#   'state': 'MI'},
#  6: {'city': 'Houston',
#   'industry': 'Petroleum Refining',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Phillips 66',
#   'state': 'TX'},
#  7: {'city': 'Fairfield',
#   'industry': 'Diversified Financials',
#   'lat': 41.1408,
#   'location': 'Fairfield, CT',
#   'lon': -73.2613,
#   'name': 'General Electric',
#   'state': 'CT'},
#  8: {'city': 'Dearborn',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 42.3223,
#   'location': 'Dearborn, MI',
#   'lon': -83.1763,
#   'name': 'Ford Motor',
#   'state': 'MI'},
#  9: {'city': 'Woonsocket',
#   'industry': 'Food and Drug Stores',
#   'lat': 42.0029,
#   'location': 'Woonsocket, RI',
#   'lon': -71.5148,
#   'name': 'CVS Health',
#   'state': 'RI'},
#  10: {'city': 'San Francisco',
#   'industry': 'Wholesalers: Health Care',
#   'lat': 37.7749,
#   'location': 'San Francisco, CA',
#   'lon': -122.419,
#   'name': 'McKesson',
#   'state': 'CA'},
#  11: {'city': 'Dallas',
#   'industry': 'Telecommunications',
#   'lat': 32.7767,
#   'location': 'Dallas, TX',
#   'lon': -96.79700000000001,
#   'name': 'AT&T',
#   'state': 'TX'},
#  12: {'city': 'San Antonio',
#   'industry': 'Petroleum Refining',
#   'lat': 29.4241,
#   'location': 'San Antonio, TX',
#   'lon': -98.4936,
#   'name': 'Valero Energy',
#   'state': 'TX'},
#  13: {'city': 'Minnetonka',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 44.9212,
#   'location': 'Minnetonka, MN',
#   'lon': -93.4687,
#   'name': 'UnitedHealth Group',
#   'state': 'MN'},
#  14: {'city': 'New York',
#   'industry': 'Telecommunications',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Verizon',
#   'state': 'NY'},
#  15: {'city': 'Chesterbrook',
#   'industry': 'Wholesalers: Health Care',
#   'lat': 40.0757,
#   'location': 'Chesterbrook, PA',
#   'lon': -75.4591,
#   'name': 'AmerisourceBergen',
#   'state': 'PA'},
#  16: {'city': 'Washington',
#   'industry': 'Diversified Financials',
#   'lat': 38.9072,
#   'location': 'Washington, DC',
#   'lon': -77.0369,
#   'name': 'Fannie Mae',
#   'state': 'DC'},
#  17: {'city': 'Issaquah',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 47.5301,
#   'location': 'Issaquah, WA',
#   'lon': -122.03299999999999,
#   'name': 'Costco',
#   'state': 'WA'},
#  18: {'city': 'Palo Alto',
#   'industry': 'Computers, Office Equipment',
#   'lat': 37.4419,
#   'location': 'Palo Alto, CA',
#   'lon': -122.14299999999999,
#   'name': 'HP',
#   'state': 'CA'},
#  19: {'city': 'Cincinnati',
#   'industry': 'Food and Drug Stores',
#   'lat': 39.1031,
#   'location': 'Cincinnati, OH',
#   'lon': -84.512,
#   'name': 'Kroger',
#   'state': 'OH'},
#  20: {'city': 'New York',
#   'industry': 'Commercial Banks',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'JP Morgan Chase',
#   'state': 'NY'},
#  21: {'city': 'St. Louis',
#   'industry': 'Health Care: Pharmacy and Other Services',
#   'lat': 38.626999999999995,
#   'location': 'St. Louis, MO',
#   'lon': -90.1994,
#   'name': 'Express Scripts Holding',
#   'state': 'MO'},
#  22: {'city': 'Charlotte',
#   'industry': 'Commercial Banks',
#   'lat': 35.2271,
#   'location': 'Charlotte, NC',
#   'lon': -80.8431,
#   'name': 'Bank of America Corp.',
#   'state': 'NC'},
#  23: {'city': 'Armonk',
#   'industry': 'Information Technology Services',
#   'lat': 41.1265,
#   'location': 'Armonk, NY',
#   'lon': -73.714,
#   'name': 'IBM',
#   'state': 'NY'},
#  24: {'city': 'Findlay',
#   'industry': 'Petroleum Refining',
#   'lat': 41.0442,
#   'location': 'Findlay, OH',
#   'lon': -83.6499,
#   'name': 'Marathon Petroleum',
#   'state': 'OH'},
#  25: {'city': 'Dublin',
#   'industry': 'Wholesalers: Health Care',
#   'lat': 40.0992,
#   'location': 'Dublin, OH',
#   'lon': -83.1141,
#   'name': 'Cardinal Health',
#   'state': 'OH'},
#  26: {'city': 'Chicago',
#   'industry': 'Aerospace and Defense',
#   'lat': 41.8781,
#   'location': 'Chicago, IL',
#   'lon': -87.6298,
#   'name': 'Boeing',
#   'state': 'IL'},
#  27: {'city': 'New York',
#   'industry': 'Commercial Banks',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Citigroup',
#   'state': 'NY'},
#  28: {'city': 'Seattle',
#   'industry': 'Internet Services and Retailing',
#   'lat': 47.6062,
#   'location': 'Seattle, WA',
#   'lon': -122.33200000000001,
#   'name': 'Amazon.com',
#   'state': 'WA'},
#  29: {'city': 'San Francisco',
#   'industry': 'Commercial Banks',
#   'lat': 37.7749,
#   'location': 'San Francisco, CA',
#   'lon': -122.419,
#   'name': 'Wells Fargo',
#   'state': 'CA'},
#  30: {'city': 'Redmond',
#   'industry': 'Computer Software',
#   'lat': 47.674,
#   'location': 'Redmond, WA',
#   'lon': -122.12200000000001,
#   'name': 'Microsoft',
#   'state': 'WA'},
#  31: {'city': 'Cincinnati',
#   'industry': 'Household and Personal Products',
#   'lat': 39.1031,
#   'location': 'Cincinnati, OH',
#   'lon': -84.512,
#   'name': 'Procter & Gamble',
#   'state': 'OH'},
#  32: {'city': 'Atlanta',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 33.749,
#   'location': 'Atlanta, GA',
#   'lon': -84.38799999999999,
#   'name': 'Home Depot',
#   'state': 'GA'},
#  33: {'city': 'Chicago',
#   'industry': 'Food Production',
#   'lat': 41.8781,
#   'location': 'Chicago, IL',
#   'lon': -87.6298,
#   'name': 'Archer Daniels Midland',
#   'state': 'IL'},
#  34: {'city': 'Deerfield',
#   'industry': 'Food and Drug Stores',
#   'lat': 42.1711,
#   'location': 'Deerfield, IL',
#   'lon': -87.8445,
#   'name': 'Walgreens',
#   'state': 'IL'},
#  35: {'city': 'Minneapolis',
#   'industry': 'General Merchandisers',
#   'lat': 44.9778,
#   'location': 'Minneapolis, MN',
#   'lon': -93.265,
#   'name': 'Target',
#   'state': 'MN'},
#  36: {'city': 'New Brunswick',
#   'industry': 'Pharmaceuticals',
#   'lat': 40.4862,
#   'location': 'New Brunswick, NJ',
#   'lon': -74.4518,
#   'name': 'Johnson & Johnson',
#   'state': 'NJ'},
#  37: {'city': 'Indianapolis',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 39.7684,
#   'location': 'Indianapolis, IN',
#   'lon': -86.1581,
#   'name': 'Anthem',
#   'state': 'IN'},
#  38: {'city': 'New York',
#   'industry': 'Insurance: Life, Health (stock)',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'MetLife',
#   'state': 'NY'},
#  39: {'city': 'Mountain View',
#   'industry': 'Internet Services and Retailing',
#   'lat': 37.3861,
#   'location': 'Mountain View, CA',
#   'lon': -122.084,
#   'name': 'Google',
#   'state': 'CA'},
#  40: {'city': 'Bloomington',
#   'industry': 'Insurance: Property and Casualty (Mutual)',
#   'lat': 40.4842,
#   'location': 'Bloomington, IL',
#   'lon': -88.9937,
#   'name': 'State Farm Insurance Cos.',
#   'state': 'IL'},
#  41: {'city': 'McLean',
#   'industry': 'Diversified Financials',
#   'lat': 38.9339,
#   'location': 'McLean, VA',
#   'lon': -77.1773,
#   'name': 'Freddie Mac',
#   'state': 'VA'},
#  42: {'city': 'Philadelphia',
#   'industry': 'Telecommunications',
#   'lat': 39.9526,
#   'location': 'Philadelphia, PA',
#   'lon': -75.1652,
#   'name': 'Comcast',
#   'state': 'PA'},
#  43: {'city': 'Purchase',
#   'industry': 'Food Consumer Products',
#   'lat': 41.0409,
#   'location': 'Purchase, NY',
#   'lon': -73.7146,
#   'name': 'PepsiCo',
#   'state': 'NY'},
#  44: {'city': 'Hartford',
#   'industry': 'Aerospace and Defense',
#   'lat': 41.7637,
#   'location': 'Hartford, CT',
#   'lon': -72.6851,
#   'name': 'United Technologies',
#   'state': 'CT'},
#  45: {'city': 'New York',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'AIG',
#   'state': 'NY'},
#  46: {'city': 'Atlanta',
#   'industry': 'Mail, Package, and Freight Delivery',
#   'lat': 33.749,
#   'location': 'Atlanta, GA',
#   'lon': -84.38799999999999,
#   'name': 'UPS',
#   'state': 'GA'},
#  47: {'city': 'Midland',
#   'industry': 'Chemicals',
#   'lat': 43.6156,
#   'location': 'Midland, MI',
#   'lon': -84.2472,
#   'name': 'Dow Chemical',
#   'state': 'MI'},
#  48: {'city': 'Hartford',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 41.7637,
#   'location': 'Hartford, CT',
#   'lon': -72.6851,
#   'name': 'Aetna',
#   'state': 'CT'},
#  49: {'city': 'Mooresville',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 35.5849,
#   'location': 'Mooresville, NC',
#   'lon': -80.8101,
#   'name': "Lowe's",
#   'state': 'NC'},
#  50: {'city': 'Houston',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'ConocoPhillips',
#   'state': 'TX'},
#  51: {'city': 'Santa Clara',
#   'industry': 'Semiconductors and Other Electronic Components',
#   'lat': 37.3541,
#   'location': 'Santa Clara, CA',
#   'lon': -121.955,
#   'name': 'Intel',
#   'state': 'CA'},
#  52: {'city': 'Dallas',
#   'industry': 'Pipelines',
#   'lat': 32.7767,
#   'location': 'Dallas, TX',
#   'lon': -96.79700000000001,
#   'name': 'Energy Transfer Equity',
#   'state': 'TX'},
#  53: {'city': 'Peoria',
#   'industry': 'Construction and Farm Machinery',
#   'lat': 40.6936,
#   'location': 'Peoria, IL',
#   'lon': -89.589,
#   'name': 'Caterpillar',
#   'state': 'IL'},
#  54: {'city': 'Newark',
#   'industry': 'Insurance: Life, Health (stock)',
#   'lat': 40.7357,
#   'location': 'Newark, NJ',
#   'lon': -74.1724,
#   'name': 'Prudential Financial',
#   'state': 'NJ'},
#  55: {'city': 'New York',
#   'industry': 'Pharmaceuticals',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Pfizer',
#   'state': 'NY'},
#  56: {'city': 'Burbank',
#   'industry': 'Entertainment',
#   'lat': 34.1808,
#   'location': 'Burbank, CA',
#   'lon': -118.309,
#   'name': 'Disney',
#   'state': 'CA'},
#  57: {'city': 'Louisville',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 38.2527,
#   'location': 'Louisville, KY',
#   'lon': -85.7585,
#   'name': 'Humana',
#   'state': 'KY'},
#  58: {'city': 'Houston',
#   'industry': 'Pipelines',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Enterprise Products Partners',
#   'state': 'TX'},
#  59: {'city': 'San Jose',
#   'industry': 'Network and Other Communications Equipment',
#   'lat': 37.3382,
#   'location': 'San Jose, CA',
#   'lon': -121.88600000000001,
#   'name': 'Cisco Systems',
#   'state': 'CA'},
#  60: {'city': 'Houston',
#   'industry': 'Wholesalers: Food and Grocery',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Sysco',
#   'state': 'TX'},
#  61: {'city': 'Santa Ana',
#   'industry': 'Wholesalers: Electronics and Office Equipment',
#   'lat': 33.7456,
#   'location': 'Santa Ana, CA',
#   'lon': -117.868,
#   'name': 'Ingram Micro',
#   'state': 'CA'},
#  62: {'city': 'Atlanta',
#   'industry': 'Beverages',
#   'lat': 33.749,
#   'location': 'Atlanta, GA',
#   'lon': -84.38799999999999,
#   'name': 'Coca-Cola',
#   'state': 'GA'},
#  63: {'city': 'Bethesda',
#   'industry': 'Aerospace and Defense',
#   'lat': 38.9847,
#   'location': 'Bethesda, MD',
#   'lon': -77.0947,
#   'name': 'Lockheed Martin',
#   'state': 'MD'},
#  64: {'city': 'Memphis',
#   'industry': 'Mail, Package, and Freight Delivery',
#   'lat': 35.1495,
#   'location': 'Memphis, TN',
#   'lon': -90.04899999999999,
#   'name': 'FedEx',
#   'state': 'TN'},
#  65: {'city': 'Milwaukee',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 43.0389,
#   'location': 'Milwaukee, WI',
#   'lon': -87.9065,
#   'name': 'Johnson Controls',
#   'state': 'WI'},
#  66: {'city': 'Houston',
#   'industry': 'Pipelines',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Plains GP Holdings',
#   'state': 'TX'},
#  67: {'city': 'Miami',
#   'industry': 'Wholesalers: Diversified',
#   'lat': 25.7617,
#   'location': 'Miami, FL',
#   'lon': -80.1918,
#   'name': 'World Fuel Services',
#   'state': 'FL'},
#  68: {'city': 'Inver Grove Heights',
#   'industry': 'Food Production',
#   'lat': 44.848,
#   'location': 'Inver Grove Heights, MN',
#   'lon': -93.0427,
#   'name': 'CHS',
#   'state': 'MN'},
#  69: {'city': 'Fort Worth',
#   'industry': 'Airlines',
#   'lat': 32.7555,
#   'location': 'Fort Worth, TX',
#   'lon': -97.3308,
#   'name': 'American Airlines Group',
#   'state': 'TX'},
#  70: {'city': 'Kenilworth',
#   'industry': 'Pharmaceuticals',
#   'lat': 40.6765,
#   'location': 'Kenilworth, NJ',
#   'lon': -74.2907,
#   'name': 'Merck',
#   'state': 'NJ'},
#  71: {'city': 'Richfield',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 44.8833,
#   'location': 'Richfield, MN',
#   'lon': -93.28299999999999,
#   'name': 'Best Buy',
#   'state': 'MN'},
#  72: {'city': 'Atlanta',
#   'industry': 'Airlines',
#   'lat': 33.749,
#   'location': 'Atlanta, GA',
#   'lon': -84.38799999999999,
#   'name': 'Delta Air Lines',
#   'state': 'GA'},
#  73: {'city': 'Morris Township',
#   'industry': 'Electronics, Electrical Equip.',
#   'lat': 40.7934,
#   'location': 'Morris Township, NJ',
#   'lon': -74.5053,
#   'name': 'Honeywell International',
#   'state': 'NJ'},
#  74: {'city': 'Nashville',
#   'industry': 'Health Care: Medical Facilities',
#   'lat': 36.1627,
#   'location': 'Nashville, TN',
#   'lon': -86.7816,
#   'name': 'HCA Holdings',
#   'state': 'TN'},
#  75: {'city': 'New York',
#   'industry': 'Commercial Banks',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Goldman Sachs Group',
#   'state': 'NY'},
#  76: {'city': 'San Antonio',
#   'industry': 'Petroleum Refining',
#   'lat': 29.4241,
#   'location': 'San Antonio, TX',
#   'lon': -98.4936,
#   'name': 'Tesoro',
#   'state': 'TX'},
#  77: {'city': 'Boston',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 42.3601,
#   'location': 'Boston, MA',
#   'lon': -71.0589,
#   'name': 'Liberty Mutual Insurance Group',
#   'state': 'MA'},
#  78: {'city': 'Chicago',
#   'industry': 'Airlines',
#   'lat': 41.8781,
#   'location': 'Chicago, IL',
#   'lon': -87.6298,
#   'name': 'United Continental Holdings',
#   'state': 'IL'},
#  79: {'city': 'New York',
#   'industry': 'Insurance: Life, Health (Mutual)',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'New York Life Insurance',
#   'state': 'NY'},
#  80: {'city': 'Redwood City',
#   'industry': 'Computer Software',
#   'lat': 37.4852,
#   'location': 'Redwood City, CA',
#   'lon': -122.236,
#   'name': 'Oracle',
#   'state': 'CA'},
#  81: {'city': 'New York',
#   'industry': 'Commercial Banks',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Morgan Stanley',
#   'state': 'NY'},
#  82: {'city': 'Springdale',
#   'industry': 'Food Production',
#   'lat': 36.1867,
#   'location': 'Springdale, AR',
#   'lon': -94.1288,
#   'name': 'Tyson Foods',
#   'state': 'AR'},
#  83: {'city': 'Pleasanton',
#   'industry': 'Food and Drug Stores',
#   'lat': 37.6624,
#   'location': 'Pleasanton, CA',
#   'lon': -121.875,
#   'name': 'Safeway',
#   'state': 'CA'},
#  84: {'city': 'Columbus',
#   'industry': 'Insurance: Property and Casualty (Mutual)',
#   'lat': 39.9612,
#   'location': 'Columbus, OH',
#   'lon': -82.9988,
#   'name': 'Nationwide',
#   'state': 'OH'},
#  85: {'city': 'Moline',
#   'industry': 'Construction and Farm Machinery',
#   'lat': 41.5067,
#   'location': 'Moline, IL',
#   'lon': -90.5151,
#   'name': 'Deere',
#   'state': 'IL'},
#  86: {'city': 'Wilmington',
#   'industry': 'Chemicals',
#   'lat': 39.7391,
#   'location': 'Wilmington, DE',
#   'lon': -75.5398,
#   'name': 'DuPont',
#   'state': 'DE'},
#  87: {'city': 'New York',
#   'industry': 'Commercial Banks',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'American Express',
#   'state': 'NY'},
#  88: {'city': 'Northbrook',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 42.1275,
#   'location': 'Northbrook, IL',
#   'lon': -87.829,
#   'name': 'Allstate',
#   'state': 'IL'},
#  89: {'city': 'Bloomfield',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 41.8265,
#   'location': 'Bloomfield, CT',
#   'lon': -72.7301,
#   'name': 'Cigna',
#   'state': 'CT'},
#  90: {'city': 'Deerfield',
#   'industry': 'Food Consumer Products',
#   'lat': 42.1711,
#   'location': 'Deerfield, IL',
#   'lon': -87.8445,
#   'name': 'Mondelez International',
#   'state': 'IL'},
#  91: {'city': 'New York',
#   'industry': 'Insurance: Life, Health (Mutual)',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'TIAA-CREF',
#   'state': 'NY'},
#  92: {'city': 'New York',
#   'industry': 'Diversified Financials',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'INTL FCStone',
#   'state': 'NY'},
#  93: {'city': 'Springfield',
#   'industry': 'Insurance: Life, Health (Mutual)',
#   'lat': 42.1015,
#   'location': 'Springfield, MA',
#   'lon': -72.5898,
#   'name': 'Massachusetts Mutual Life Insurance',
#   'state': 'MA'},
#  94: {'city': 'El Segundo',
#   'industry': 'Telecommunications',
#   'lat': 33.9192,
#   'location': 'El Segundo, CA',
#   'lon': -118.416,
#   'name': 'DirecTV',
#   'state': 'CA'},
#  95: {'city': 'Houston',
#   'industry': 'Oil and Gas Equipment, Services',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Halliburton',
#   'state': 'TX'},
#  96: {'city': 'New York',
#   'industry': 'Entertainment',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Twenty-First Century Fox',
#   'state': 'NY'},
#  97: {'city': 'St. Paul',
#   'industry': 'zMiscellaneous',
#   'lat': 44.9537,
#   'location': 'St. Paul, MN',
#   'lon': -93.09,
#   'name': '3M',
#   'state': 'MN'},
#  98: {'city': 'Hoffman Estates',
#   'industry': 'General Merchandisers',
#   'lat': 42.063,
#   'location': 'Hoffman Estates, IL',
#   'lon': -88.1227,
#   'name': 'Sears Holdings',
#   'state': 'IL'},
#  99: {'city': 'Falls Church',
#   'industry': 'Aerospace and Defense',
#   'lat': 38.8823,
#   'location': 'Falls Church, VA',
#   'lon': -77.1711,
#   'name': 'General Dynamics',
#   'state': 'VA'},
#  100: {'city': 'Lakeland',
#   'industry': 'Food and Drug Stores',
#   'lat': 28.0395,
#   'location': 'Lakeland, FL',
#   'lon': -81.9498,
#   'name': 'Publix Super Markets',
#   'state': 'FL'},
#  101: {'city': 'New York',
#   'industry': 'Tobacco',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Philip Morris International',
#   'state': 'NY'},
#  102: {'city': 'Framingham',
#   'industry': 'Specialty Retailers: Apparel',
#   'lat': 42.2793,
#   'location': 'Framingham, MA',
#   'lon': -71.4162,
#   'name': 'TJX',
#   'state': 'MA'},
#  103: {'city': 'New York',
#   'industry': 'Entertainment',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Time Warner',
#   'state': 'NY'},
#  104: {'city': 'Cincinnati',
#   'industry': 'General Merchandisers',
#   'lat': 39.1031,
#   'location': 'Cincinnati, OH',
#   'lon': -84.512,
#   'name': "Macy's",
#   'state': 'OH'},
#  105: {'city': 'Beaverton',
#   'industry': 'Apparel',
#   'lat': 45.4871,
#   'location': 'Beaverton, OR',
#   'lon': -122.804,
#   'name': 'Nike',
#   'state': 'OR'},
#  106: {'city': 'Clearwater',
#   'industry': 'Wholesalers: Electronics and Office Equipment',
#   'lat': 27.9659,
#   'location': 'Clearwater, FL',
#   'lon': -82.8001,
#   'name': 'Tech Data',
#   'state': 'FL'},
#  107: {'city': 'Phoenix',
#   'industry': 'Wholesalers: Electronics and Office Equipment',
#   'lat': 33.4484,
#   'location': 'Phoenix, AZ',
#   'lon': -112.074,
#   'name': 'Avnet',
#   'state': 'AZ'},
#  108: {'city': 'Milwaukee',
#   'industry': 'Insurance: Life, Health (Mutual)',
#   'lat': 43.0389,
#   'location': 'Milwaukee, WI',
#   'lon': -87.9065,
#   'name': 'Northwestern Mutual',
#   'state': 'WI'},
#  109: {'city': 'Oak Brook',
#   'industry': 'Food Services',
#   'lat': 41.8398,
#   'location': 'Oak Brook, IL',
#   'lon': -87.9536,
#   'name': "McDonald's",
#   'state': 'IL'},
#  110: {'city': 'Chicago',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 41.8781,
#   'location': 'Chicago, IL',
#   'lon': -87.6298,
#   'name': 'Exelon',
#   'state': 'IL'},
#  111: {'city': 'New York',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Travelers Cos.',
#   'state': 'NY'},
#  112: {'city': 'San Diego',
#   'industry': 'Network and Other Communications Equipment',
#   'lat': 32.7157,
#   'location': 'San Diego, CA',
#   'lon': -117.161,
#   'name': 'Qualcomm',
#   'state': 'CA'},
#  113: {'city': 'Memphis',
#   'industry': 'Packaging, Containers',
#   'lat': 35.1495,
#   'location': 'Memphis, TN',
#   'lon': -90.04899999999999,
#   'name': 'International Paper',
#   'state': 'TN'},
#  114: {'city': 'Houston',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Occidental Petroleum',
#   'state': 'TX'},
#  115: {'city': 'Charlotte',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 35.2271,
#   'location': 'Charlotte, NC',
#   'lon': -80.8431,
#   'name': 'Duke Energy',
#   'state': 'NC'},
#  116: {'city': 'Camp Hill',
#   'industry': 'Food and Drug Stores',
#   'lat': 40.2398,
#   'location': 'Camp Hill, PA',
#   'lon': -76.92,
#   'name': 'Rite Aid',
#   'state': 'PA'},
#  117: {'city': 'Foster City',
#   'industry': 'Pharmaceuticals',
#   'lat': 37.5585,
#   'location': 'Foster City, CA',
#   'lon': -122.271,
#   'name': 'Gilead Sciences',
#   'state': 'CA'},
#  118: {'city': 'Houston',
#   'industry': 'Oil and Gas Equipment, Services',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Baker Hughes',
#   'state': 'TX'},
#  119: {'city': 'St. Louis',
#   'industry': 'Electronics, Electrical Equip.',
#   'lat': 38.626999999999995,
#   'location': 'St. Louis, MO',
#   'lon': -90.1994,
#   'name': 'Emerson Electric',
#   'state': 'MO'},
#  120: {'city': 'Hopkinton',
#   'industry': 'Computer Peripherals',
#   'lat': 42.2287,
#   'location': 'Hopkinton, MA',
#   'lon': -71.5226,
#   'name': 'EMC',
#   'state': 'MA'},
#  121: {'city': 'San Antonio',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 29.4241,
#   'location': 'San Antonio, TX',
#   'lon': -98.4936,
#   'name': 'USAA',
#   'state': 'TX'},
#  122: {'city': 'Omaha',
#   'industry': 'Railroads',
#   'lat': 41.2524,
#   'location': 'Omaha, NE',
#   'lon': -95.99799999999999,
#   'name': 'Union Pacific',
#   'state': 'NE'},
#  123: {'city': 'Falls Church',
#   'industry': 'Aerospace and Defense',
#   'lat': 38.8823,
#   'location': 'Falls Church, VA',
#   'lon': -77.1711,
#   'name': 'Northrop Grumman',
#   'state': 'VA'},
#  124: {'city': 'New York',
#   'industry': 'Metals',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Alcoa',
#   'state': 'NY'},
#  125: {'city': 'McLean',
#   'industry': 'Commercial Banks',
#   'lat': 38.9339,
#   'location': 'McLean, VA',
#   'lon': -77.1773,
#   'name': 'Capital One Financial',
#   'state': 'VA'},
#  126: {'city': 'Houston',
#   'industry': 'Oil and Gas Equipment, Services',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'National Oilwell Varco',
#   'state': 'TX'},
#  127: {'city': 'Rosemont',
#   'industry': 'Wholesalers: Food and Grocery',
#   'lat': 41.9868,
#   'location': 'Rosemont, IL',
#   'lon': -87.8722,
#   'name': 'US Foods',
#   'state': 'IL'},
#  128: {'city': 'Waltham',
#   'industry': 'Aerospace and Defense',
#   'lat': 42.3765,
#   'location': 'Waltham, MA',
#   'lon': -71.2356,
#   'name': 'Raytheon',
#   'state': 'MA'},
#  129: {'city': 'New York',
#   'industry': 'Telecommunications',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Time Warner Cable',
#   'state': 'NY'},
#  130: {'city': 'Centennial',
#   'industry': 'Wholesalers: Electronics and Office Equipment',
#   'lat': 39.5807,
#   'location': 'Centennial, CO',
#   'lon': -104.87700000000001,
#   'name': 'Arrow Electronics',
#   'state': 'CO'},
#  131: {'city': 'Columbus',
#   'industry': 'Insurance: Life, Health (stock)',
#   'lat': 32.461,
#   'location': 'Columbus, GA',
#   'lon': -84.9877,
#   'name': 'Aflac',
#   'state': 'GA'},
#  132: {'city': 'Framingham',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 42.2793,
#   'location': 'Framingham, MA',
#   'lon': -71.4162,
#   'name': 'Staples',
#   'state': 'MA'},
#  133: {'city': 'Abbott Park',
#   'industry': 'Medical Products and Equipment',
#   'lat': 42.3045,
#   'location': 'Abbott Park, IL',
#   'lon': -87.8961,
#   'name': 'Abbott Laboratories',
#   'state': 'IL'},
#  134: {'city': 'Franklin',
#   'industry': 'Health Care: Medical Facilities',
#   'lat': 35.9251,
#   'location': 'Franklin, TN',
#   'lon': -86.8689,
#   'name': 'Community Health Systems',
#   'state': 'TN'},
#  135: {'city': 'Irving',
#   'industry': 'Engineering, Construction',
#   'lat': 32.814,
#   'location': 'Irving, TX',
#   'lon': -96.9489,
#   'name': 'Fluor',
#   'state': 'TX'},
#  136: {'city': 'Phoenix',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 33.4484,
#   'location': 'Phoenix, AZ',
#   'lon': -112.074,
#   'name': 'Freeport-McMoRan',
#   'state': 'AZ'},
#  137: {'city': 'Minneapolis',
#   'industry': 'Commercial Banks',
#   'lat': 44.9778,
#   'location': 'Minneapolis, MN',
#   'lon': -93.265,
#   'name': 'U.S. Bancorp',
#   'state': 'MN'},
#  138: {'city': 'Charlotte',
#   'industry': 'Metals',
#   'lat': 35.2271,
#   'location': 'Charlotte, NC',
#   'lon': -80.8431,
#   'name': 'Nucor',
#   'state': 'NC'},
#  139: {'city': 'Irving',
#   'industry': 'Household and Personal Products',
#   'lat': 32.814,
#   'location': 'Irving, TX',
#   'lon': -96.9489,
#   'name': 'Kimberly-Clark',
#   'state': 'TX'},
#  140: {'city': 'New York',
#   'industry': 'Petroleum Refining',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Hess',
#   'state': 'NY'},
#  141: {'city': 'Oklahoma City',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 35.4676,
#   'location': 'Oklahoma City, OK',
#   'lon': -97.5164,
#   'name': 'Chesapeake Energy',
#   'state': 'OK'},
#  142: {'city': 'Norwalk',
#   'industry': 'Information Technology Services',
#   'lat': 41.1177,
#   'location': 'Norwalk, CT',
#   'lon': -73.4082,
#   'name': 'Xerox',
#   'state': 'CT'},
#  143: {'city': 'Milwaukee',
#   'industry': 'Temporary Help',
#   'lat': 43.0389,
#   'location': 'Milwaukee, WI',
#   'lon': -87.9065,
#   'name': 'ManpowerGroup',
#   'state': 'WI'},
#  144: {'city': 'Thousand Oaks',
#   'industry': 'Pharmaceuticals',
#   'lat': 34.1706,
#   'location': 'Thousand Oaks, CA',
#   'lon': -118.838,
#   'name': 'Amgen',
#   'state': 'CA'},
#  145: {'city': 'North Chicago',
#   'industry': 'Pharmaceuticals',
#   'lat': 42.3256,
#   'location': 'North Chicago, IL',
#   'lon': -87.8412,
#   'name': 'AbbVie',
#   'state': 'IL'},
#  146: {'city': 'Washington',
#   'industry': 'Scientific,Photographic and Control Equipment',
#   'lat': 38.9072,
#   'location': 'Washington, DC',
#   'lon': -77.0369,
#   'name': 'Danaher',
#   'state': 'DC'},
#  147: {'city': 'Benton Harbor',
#   'industry': 'Electronics, Electrical Equip.',
#   'lat': 42.1167,
#   'location': 'Benton Harbor, MI',
#   'lon': -86.4542,
#   'name': 'Whirlpool',
#   'state': 'MI'},
#  148: {'city': 'Parsippany',
#   'industry': 'Petroleum Refining',
#   'lat': 40.8653,
#   'location': 'Parsippany, NJ',
#   'lon': -74.4174,
#   'name': 'PBF Energy',
#   'state': 'NJ'},
#  149: {'city': 'Dallas',
#   'industry': 'Petroleum Refining',
#   'lat': 32.7767,
#   'location': 'Dallas, TX',
#   'lon': -96.79700000000001,
#   'name': 'HollyFrontier',
#   'state': 'TX'},
#  150: {'city': 'Indianapolis',
#   'industry': 'Pharmaceuticals',
#   'lat': 39.7684,
#   'location': 'Indianapolis, IN',
#   'lon': -86.1581,
#   'name': 'Eli Lilly',
#   'state': 'IN'},
#  151: {'city': 'Oklahoma City',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 35.4676,
#   'location': 'Oklahoma City, OK',
#   'lon': -97.5164,
#   'name': 'Devon Energy',
#   'state': 'OK'},
#  152: {'city': 'Mayfield Village',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 41.552,
#   'location': 'Mayfield Village, OH',
#   'lon': -81.4393,
#   'name': 'Progressive',
#   'state': 'OH'},
#  153: {'city': 'Columbus',
#   'industry': 'Construction and Farm Machinery',
#   'lat': 39.2014,
#   'location': 'Columbus, IN',
#   'lon': -85.9214,
#   'name': 'Cummins',
#   'state': 'IN'},
#  154: {'city': 'New York',
#   'industry': 'Petroleum Refining',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Icahn Enterprises',
#   'state': 'NY'},
#  155: {'city': 'Fort Lauderdale',
#   'industry': 'Automotive Retailing, Services',
#   'lat': 26.1224,
#   'location': 'Fort Lauderdale, FL',
#   'lon': -80.1373,
#   'name': 'AutoNation',
#   'state': 'FL'},
#  156: {'city': 'Menomonee Falls',
#   'industry': 'General Merchandisers',
#   'lat': 43.1789,
#   'location': 'Menomonee Falls, WI',
#   'lon': -88.1173,
#   'name': "Kohl's",
#   'state': 'WI'},
#  157: {'city': 'Bellevue',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 47.6104,
#   'location': 'Bellevue, WA',
#   'lon': -122.20100000000001,
#   'name': 'Paccar',
#   'state': 'WA'},
#  158: {'city': 'Goodlettsville',
#   'industry': 'General Merchandisers',
#   'lat': 36.3231,
#   'location': 'Goodlettsville, TN',
#   'lon': -86.7133,
#   'name': 'Dollar General',
#   'state': 'TN'},
#  159: {'city': 'Hartford',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 41.7637,
#   'location': 'Hartford, CT',
#   'lon': -72.6851,
#   'name': 'Hartford Financial Services Group',
#   'state': 'CT'},
#  160: {'city': 'Dallas',
#   'industry': 'Airlines',
#   'lat': 32.7767,
#   'location': 'Dallas, TX',
#   'lon': -96.79700000000001,
#   'name': 'Southwest Airlines',
#   'state': 'TX'},
#  161: {'city': 'The Woodlands',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 30.1658,
#   'location': 'The Woodlands, TX',
#   'lon': -95.4613,
#   'name': 'Anadarko Petroleum',
#   'state': 'TX'},
#  162: {'city': 'Atlanta',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 33.749,
#   'location': 'Atlanta, GA',
#   'lon': -84.38799999999999,
#   'name': 'Southern',
#   'state': 'GA'},
#  163: {'city': 'Eden Prairie',
#   'industry': 'Food and Drug Stores',
#   'lat': 44.8547,
#   'location': 'Eden Prairie, MN',
#   'lon': -93.4708,
#   'name': 'Supervalu',
#   'state': 'MN'},
#  164: {'city': 'Northfield',
#   'industry': 'Food Consumer Products',
#   'lat': 42.0998,
#   'location': 'Northfield, IL',
#   'lon': -87.7809,
#   'name': 'Kraft Foods Group',
#   'state': 'IL'},
#  165: {'city': 'Akron',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 41.0814,
#   'location': 'Akron, OH',
#   'lon': -81.51899999999999,
#   'name': 'Goodyear Tire & Rubber',
#   'state': 'OH'},
#  166: {'city': 'Houston',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'EOG Resources',
#   'state': 'TX'},
#  167: {'city': 'Monroe',
#   'industry': 'Telecommunications',
#   'lat': 32.5093,
#   'location': 'Monroe, LA',
#   'lon': -92.1193,
#   'name': 'CenturyLink',
#   'state': 'LA'},
#  168: {'city': 'Richmond',
#   'industry': 'Tobacco',
#   'lat': 37.5407,
#   'location': 'Richmond, VA',
#   'lon': -77.436,
#   'name': 'Altria Group',
#   'state': 'VA'},
#  169: {'city': 'Dallas',
#   'industry': 'Health Care: Medical Facilities',
#   'lat': 32.7767,
#   'location': 'Dallas, TX',
#   'lon': -96.79700000000001,
#   'name': 'Tenet Healthcare',
#   'state': 'TX'},
#  170: {'city': 'Minneapolis',
#   'industry': 'Food Consumer Products',
#   'lat': 44.9778,
#   'location': 'Minneapolis, MN',
#   'lon': -93.265,
#   'name': 'General Mills',
#   'state': 'MN'},
#  171: {'city': 'San Jose',
#   'industry': 'Internet Services and Retailing',
#   'lat': 37.3382,
#   'location': 'San Jose, CA',
#   'lon': -121.88600000000001,
#   'name': 'eBay',
#   'state': 'CA'},
#  172: {'city': 'Omaha',
#   'industry': 'Food Consumer Products',
#   'lat': 41.2524,
#   'location': 'Omaha, NE',
#   'lon': -95.99799999999999,
#   'name': 'ConAgra Foods',
#   'state': 'NE'},
#  173: {'city': 'Southfield',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 42.4734,
#   'location': 'Southfield, MI',
#   'lon': -83.2219,
#   'name': 'Lear',
#   'state': 'MI'},
#  174: {'city': 'Livonia',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 42.3684,
#   'location': 'Livonia, MI',
#   'lon': -83.3527,
#   'name': 'TRW Automotive Holdings',
#   'state': 'MI'},
#  175: {'city': 'Pittsburgh',
#   'industry': 'Metals',
#   'lat': 40.4406,
#   'location': 'Pittsburgh, PA',
#   'lon': -79.9959,
#   'name': 'United States Steel',
#   'state': 'PA'},
#  176: {'city': 'Bloomfield Hills',
#   'industry': 'Automotive Retailing, Services',
#   'lat': 42.5836,
#   'location': 'Bloomfield Hills, MI',
#   'lon': -83.2455,
#   'name': 'Penske Automotive Group',
#   'state': 'MI'},
#  177: {'city': 'Arlington',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 38.88,
#   'location': 'Arlington, VA',
#   'lon': -77.1068,
#   'name': 'AES',
#   'state': 'VA'},
#  178: {'city': 'New York',
#   'industry': 'Household and Personal Products',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Colgate-Palmolive',
#   'state': 'NY'},
#  179: {'city': 'Waltham',
#   'industry': 'Wholesalers: Diversified',
#   'lat': 42.3765,
#   'location': 'Waltham, MA',
#   'lon': -71.2356,
#   'name': 'Global Partners',
#   'state': 'MA'},
#  180: {'city': 'Waltham',
#   'industry': 'Scientific,Photographic and Control Equipment',
#   'lat': 42.3765,
#   'location': 'Waltham, MA',
#   'lon': -71.2356,
#   'name': 'Thermo Fisher Scientific',
#   'state': 'MA'},
#  181: {'city': 'San Francisco',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 37.7749,
#   'location': 'San Francisco, CA',
#   'lon': -122.419,
#   'name': 'PG&E Corp.',
#   'state': 'CA'},
#  182: {'city': 'Juno Beach',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 26.8798,
#   'location': 'Juno Beach, FL',
#   'lon': -80.0534,
#   'name': 'NextEra Energy',
#   'state': 'FL'},
#  183: {'city': 'Columbus',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 39.9612,
#   'location': 'Columbus, OH',
#   'lon': -82.9988,
#   'name': 'American Electric Power',
#   'state': 'OH'},
#  184: {'city': 'Deerfield',
#   'industry': 'Medical Products and Equipment',
#   'lat': 42.1711,
#   'location': 'Deerfield, IL',
#   'lon': -87.8445,
#   'name': 'Baxter International',
#   'state': 'IL'},
#  185: {'city': 'St. Louis',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 38.626999999999995,
#   'location': 'St. Louis, MO',
#   'lon': -90.1994,
#   'name': 'Centene',
#   'state': 'MO'},
#  186: {'city': 'Seattle',
#   'industry': 'Food Services',
#   'lat': 47.6062,
#   'location': 'Seattle, WA',
#   'lon': -122.33200000000001,
#   'name': 'Starbucks',
#   'state': 'WA'},
#  187: {'city': 'San Francisco',
#   'industry': 'Specialty Retailers: Apparel',
#   'lat': 37.7749,
#   'location': 'San Francisco, CA',
#   'lon': -122.419,
#   'name': 'Gap',
#   'state': 'CA'},
#  188: {'city': 'New York',
#   'industry': 'Commercial Banks',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Bank of New York Mellon Corp.',
#   'state': 'NY'},
#  189: {'city': 'Boise',
#   'industry': 'Semiconductors and Other Electronic Components',
#   'lat': 43.6187,
#   'location': 'Boise, ID',
#   'lon': -116.215,
#   'name': 'Micron Technology',
#   'state': 'ID'},
#  190: {'city': 'St. Petersburg',
#   'industry': 'Semiconductors and Other Electronic Components',
#   'lat': 27.7731,
#   'location': 'St. Petersburg, FL',
#   'lon': -82.64,
#   'name': 'Jabil Circuit',
#   'state': 'FL'},
#  191: {'city': 'Pittsburgh',
#   'industry': 'Commercial Banks',
#   'lat': 40.4406,
#   'location': 'Pittsburgh, PA',
#   'lon': -79.9959,
#   'name': 'PNC Financial Services Group',
#   'state': 'PA'},
#  192: {'city': 'Houston',
#   'industry': 'Pipelines',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Kinder Morgan',
#   'state': 'TX'},
#  193: {'city': 'Boca Raton',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 26.3683,
#   'location': 'Boca Raton, FL',
#   'lon': -80.1289,
#   'name': 'Office Depot',
#   'state': 'FL'},
#  194: {'city': 'New York',
#   'industry': 'Pharmaceuticals',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Bristol-Myers Squibb',
#   'state': 'NY'},
#  195: {'city': 'Princeton',
#   'industry': 'Energy',
#   'lat': 40.3573,
#   'location': 'Princeton, NJ',
#   'lon': -74.6672,
#   'name': 'NRG Energy',
#   'state': 'NJ'},
#  196: {'city': 'St. Louis',
#   'industry': 'Chemicals',
#   'lat': 38.626999999999995,
#   'location': 'St. Louis, MO',
#   'lon': -90.1994,
#   'name': 'Monsanto',
#   'state': 'MO'},
#  197: {'city': 'Pittsburgh',
#   'industry': 'Chemicals',
#   'lat': 40.4406,
#   'location': 'Pittsburgh, PA',
#   'lon': -79.9959,
#   'name': 'PPG Industries',
#   'state': 'PA'},
#  198: {'city': 'Atlanta',
#   'industry': 'Wholesalers: Diversified',
#   'lat': 33.749,
#   'location': 'Atlanta, GA',
#   'lon': -84.38799999999999,
#   'name': 'Genuine Parts',
#   'state': 'GA'},
#  199: {'city': 'New York',
#   'industry': 'Advertising, marketing',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Omnicom Group',
#   'state': 'NY'},
#  200: {'city': 'Glenview',
#   'industry': 'Industrial Machinery',
#   'lat': 42.0698,
#   'location': 'Glenview, IL',
#   'lon': -87.7878,
#   'name': 'Illinois Tool Works',
#   'state': 'IL'},
#  201: {'city': 'El Dorado',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 33.2076,
#   'location': 'El Dorado, AR',
#   'lon': -92.6663,
#   'name': 'Murphy USA',
#   'state': 'AR'},
#  202: {'city': 'Arden Hills',
#   'industry': 'Food Consumer Products',
#   'lat': 45.0502,
#   'location': 'Arden Hills, MN',
#   'lon': -93.1566,
#   'name': "Land O'Lakes",
#   'state': 'MN'},
#  203: {'city': 'El Paso',
#   'industry': 'Petroleum Refining',
#   'lat': 31.7776,
#   'location': 'El Paso, TX',
#   'lon': -106.44200000000001,
#   'name': 'Western Refining',
#   'state': 'TX'},
#  204: {'city': 'Irvine',
#   'industry': 'Computer Peripherals',
#   'lat': 33.6839,
#   'location': 'Irvine, CA',
#   'lon': -117.795,
#   'name': 'Western Digital',
#   'state': 'CA'},
#  205: {'city': 'Akron',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 41.0814,
#   'location': 'Akron, OH',
#   'lon': -81.51899999999999,
#   'name': 'FirstEnergy',
#   'state': 'OH'},
#  206: {'city': 'Philadelphia',
#   'industry': 'Diversified Outsourcing Services',
#   'lat': 39.9526,
#   'location': 'Philadelphia, PA',
#   'lon': -75.1652,
#   'name': 'Aramark',
#   'state': 'PA'},
#  207: {'city': 'Englewood',
#   'industry': 'Telecommunications',
#   'lat': 39.6478,
#   'location': 'Englewood, CO',
#   'lon': -104.988,
#   'name': 'DISH Network',
#   'state': 'CO'},
#  208: {'city': 'Las Vegas',
#   'industry': 'Hotels, Casinos, Resorts',
#   'lat': 36.1699,
#   'location': 'Las Vegas, NV',
#   'lon': -115.14,
#   'name': 'Las Vegas Sands',
#   'state': 'NV'},
#  209: {'city': 'Battle Creek',
#   'industry': 'Food Consumer Products',
#   'lat': 42.3212,
#   'location': 'Battle Creek, MI',
#   'lon': -85.1797,
#   'name': 'Kellogg',
#   'state': 'MI'},
#  210: {'city': 'New York',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Loews',
#   'state': 'NY'},
#  211: {'city': 'New York',
#   'industry': 'Entertainment',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'CBS',
#   'state': 'NY'},
#  212: {'city': 'St. Paul',
#   'industry': 'Chemicals',
#   'lat': 44.9537,
#   'location': 'St. Paul, MN',
#   'lon': -93.09,
#   'name': 'Ecolab',
#   'state': 'MN'},
#  213: {'city': 'Austin',
#   'industry': 'Food and Drug Stores',
#   'lat': 30.2672,
#   'location': 'Austin, TX',
#   'lon': -97.7431,
#   'name': 'Whole Foods Market',
#   'state': 'TX'},
#  214: {'city': 'Warren',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 40.6342,
#   'location': 'Warren, NJ',
#   'lon': -74.5005,
#   'name': 'Chubb',
#   'state': 'NJ'},
#  215: {'city': 'Woodland Hills',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 34.1654,
#   'location': 'Woodland Hills, CA',
#   'lon': -118.609,
#   'name': 'Health Net',
#   'state': 'CA'},
#  216: {'city': 'Houston',
#   'industry': 'Waste Management',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Waste Management',
#   'state': 'TX'},
#  217: {'city': 'Houston',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Apache',
#   'state': 'TX'},
#  218: {'city': 'Providence',
#   'industry': 'Aerospace and Defense',
#   'lat': 41.824,
#   'location': 'Providence, RI',
#   'lon': -71.4128,
#   'name': 'Textron',
#   'state': 'RI'},
#  219: {'city': 'Fremont',
#   'industry': 'Wholesalers: Electronics and Office Equipment',
#   'lat': 37.5483,
#   'location': 'Fremont, CA',
#   'lon': -121.98899999999999,
#   'name': 'Synnex',
#   'state': 'CA'},
#  220: {'city': 'Bethesda',
#   'industry': 'Hotels, Casinos, Resorts',
#   'lat': 38.9847,
#   'location': 'Bethesda, MD',
#   'lon': -77.0947,
#   'name': 'Marriott International',
#   'state': 'MD'},
#  221: {'city': 'New York',
#   'industry': 'Entertainment',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Viacom',
#   'state': 'NY'},
#  222: {'city': 'Radnor',
#   'industry': 'Insurance: Life, Health (stock)',
#   'lat': 40.0462,
#   'location': 'Radnor, PA',
#   'lon': -75.3599,
#   'name': 'Lincoln National',
#   'state': 'PA'},
#  223: {'city': 'Seattle',
#   'industry': 'General Merchandisers',
#   'lat': 47.6062,
#   'location': 'Seattle, WA',
#   'lon': -122.33200000000001,
#   'name': 'Nordstrom',
#   'state': 'WA'},
#  224: {'city': 'Eden Prairie',
#   'industry': 'Transportation and Logistics',
#   'lat': 44.8547,
#   'location': 'Eden Prairie, MN',
#   'lon': -93.4708,
#   'name': 'C.H. Robinson Worldwide',
#   'state': 'MN'},
#  225: {'city': 'Rosemead',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 34.0806,
#   'location': 'Rosemead, CA',
#   'lon': -118.073,
#   'name': 'Edison International',
#   'state': 'CA'},
#  226: {'city': 'Houston',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Marathon Oil',
#   'state': 'TX'},
#  227: {'city': 'Louisville',
#   'industry': 'Food Services',
#   'lat': 38.2527,
#   'location': 'Louisville, KY',
#   'lon': -85.7585,
#   'name': 'Yum Brands',
#   'state': 'KY'},
#  228: {'city': 'Falls Church',
#   'industry': 'Information Technology Services',
#   'lat': 38.8823,
#   'location': 'Falls Church, VA',
#   'lon': -77.1711,
#   'name': 'Computer Sciences',
#   'state': 'VA'},
#  229: {'city': 'Cleveland',
#   'industry': 'Industrial Machinery',
#   'lat': 41.4993,
#   'location': 'Cleveland, OH',
#   'lon': -81.6944,
#   'name': 'Parker-Hannifin',
#   'state': 'OH'},
#  230: {'city': 'Denver',
#   'industry': 'Health Care: Medical Facilities',
#   'lat': 39.7392,
#   'location': 'Denver, CO',
#   'lon': -104.99,
#   'name': 'DaVita HealthCare Partners',
#   'state': 'CO'},
#  231: {'city': 'Richmond',
#   'industry': 'Automotive Retailing, Services',
#   'lat': 37.5407,
#   'location': 'Richmond, VA',
#   'lon': -77.436,
#   'name': 'CarMax',
#   'state': 'VA'},
#  232: {'city': 'Dallas',
#   'industry': 'Semiconductors and Other Electronic Components',
#   'lat': 32.7767,
#   'location': 'Dallas, TX',
#   'lon': -96.79700000000001,
#   'name': 'Texas Instruments',
#   'state': 'TX'},
#  233: {'city': 'Tampa',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 27.9506,
#   'location': 'Tampa, FL',
#   'lon': -82.4572,
#   'name': 'WellCare Health Plans',
#   'state': 'FL'},
#  234: {'city': 'New York',
#   'industry': 'Diversified Financials',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Marsh & McLennan',
#   'state': 'NY'},
#  235: {'city': 'New York',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Consolidated Edison',
#   'state': 'NY'},
#  236: {'city': 'Tulsa',
#   'industry': 'Pipelines',
#   'lat': 36.154,
#   'location': 'Tulsa, OK',
#   'lon': -95.9928,
#   'name': 'Oneok',
#   'state': 'OK'},
#  237: {'city': 'Foster City',
#   'industry': 'Financial Data Services',
#   'lat': 37.5585,
#   'location': 'Foster City, CA',
#   'lon': -122.271,
#   'name': 'Visa',
#   'state': 'CA'},
#  238: {'city': 'Pasadena',
#   'industry': 'Engineering, Construction',
#   'lat': 34.1478,
#   'location': 'Pasadena, CA',
#   'lon': -118.145,
#   'name': 'Jacobs Engineering Group',
#   'state': 'CA'},
#  239: {'city': 'Jacksonville',
#   'industry': 'Railroads',
#   'lat': 30.3322,
#   'location': 'Jacksonville, FL',
#   'lon': -81.6557,
#   'name': 'CSX',
#   'state': 'FL'},
#  240: {'city': 'New Orleans',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 29.9511,
#   'location': 'New Orleans, LA',
#   'lon': -90.0715,
#   'name': 'Entergy',
#   'state': 'LA'},
#  241: {'city': 'Menlo Park',
#   'industry': 'Internet Services and Retailing',
#   'lat': 37.453,
#   'location': 'Menlo Park, CA',
#   'lon': -122.182,
#   'name': 'Facebook',
#   'state': 'CA'},
#  242: {'city': 'Richmond',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 37.5407,
#   'location': 'Richmond, VA',
#   'lon': -77.436,
#   'name': 'Dominion Resources',
#   'state': 'VA'},
#  243: {'city': 'New York',
#   'industry': 'Food Production',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Leucadia National',
#   'state': 'NY'},
#  244: {'city': 'Wayne',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 40.9254,
#   'location': 'Wayne, NJ',
#   'lon': -74.2765,
#   'name': 'Toys "R" Us',
#   'state': 'NJ'},
#  245: {'city': 'Detroit',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 42.3314,
#   'location': 'Detroit, MI',
#   'lon': -83.0458,
#   'name': 'DTE Energy',
#   'state': 'MI'},
#  246: {'city': 'Minneapolis',
#   'industry': 'Diversified Financials',
#   'lat': 44.9778,
#   'location': 'Minneapolis, MN',
#   'lon': -93.265,
#   'name': 'Ameriprise Financial',
#   'state': 'MN'},
#  247: {'city': 'Greensboro',
#   'industry': 'Apparel',
#   'lat': 36.0726,
#   'location': 'Greensboro, NC',
#   'lon': -79.792,
#   'name': 'VF',
#   'state': 'NC'},
#  248: {'city': 'Danbury',
#   'industry': 'Chemicals',
#   'lat': 41.3948,
#   'location': 'Danbury, CT',
#   'lon': -73.454,
#   'name': 'Praxair',
#   'state': 'CT'},
#  249: {'city': 'Plano',
#   'industry': 'General Merchandisers',
#   'lat': 33.0198,
#   'location': 'Plano, TX',
#   'lon': -96.6989,
#   'name': 'J.C. Penney',
#   'state': 'TX'},
#  250: {'city': 'Roseland',
#   'industry': 'Diversified Outsourcing Services',
#   'lat': 40.8207,
#   'location': 'Roseland, NJ',
#   'lon': -74.2938,
#   'name': 'Automatic Data Processing',
#   'state': 'NJ'},
#  251: {'city': 'New York',
#   'industry': 'Aerospace and Defense',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'L-3 Communications',
#   'state': 'NY'},
#  252: {'city': 'Vernon Hills',
#   'industry': 'Information Technology Services',
#   'lat': 42.2393,
#   'location': 'Vernon Hills, IL',
#   'lon': -87.9654,
#   'name': 'CDW',
#   'state': 'IL'},
#  253: {'city': 'New York',
#   'industry': 'Insurance: Life, Health (Mutual)',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'Guardian Life Ins. Co. of America',
#   'state': 'NY'},
#  254: {'city': 'Minneapolis',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 44.9778,
#   'location': 'Minneapolis, MN',
#   'lon': -93.265,
#   'name': 'Xcel Energy',
#   'state': 'MN'},
#  255: {'city': 'Norfolk',
#   'industry': 'Railroads',
#   'lat': 36.8508,
#   'location': 'Norfolk, VA',
#   'lon': -76.2859,
#   'name': 'Norfolk Southern',
#   'state': 'VA'},
#  256: {'city': 'Allentown',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 40.6084,
#   'location': 'Allentown, PA',
#   'lon': -75.4902,
#   'name': 'PPL',
#   'state': 'PA'},
#  257: {'city': 'Chicago',
#   'industry': 'Publishing, Printing',
#   'lat': 41.8781,
#   'location': 'Chicago, IL',
#   'lon': -87.6298,
#   'name': 'R.R. Donnelley & Sons',
#   'state': 'IL'},
#  258: {'city': 'Salt Lake City',
#   'industry': 'Chemicals',
#   'lat': 40.7608,
#   'location': 'Salt Lake City, UT',
#   'lon': -111.891,
#   'name': 'Huntsman',
#   'state': 'UT'},
#  259: {'city': 'Union',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 40.6976,
#   'location': 'Union, NJ',
#   'lon': -74.2632,
#   'name': 'Bed Bath & Beyond',
#   'state': 'NJ'},
#  260: {'city': 'New Britain',
#   'industry': 'Home Equipment, Furnishings',
#   'lat': 41.6612,
#   'location': 'New Britain, CT',
#   'lon': -72.7795,
#   'name': 'Stanley Black & Decker',
#   'state': 'CT'},
#  261: {'city': 'Columbus',
#   'industry': 'Specialty Retailers: Apparel',
#   'lat': 39.9612,
#   'location': 'Columbus, OH',
#   'lon': -82.9988,
#   'name': 'L Brands',
#   'state': 'OH'},
# ...
#   'location': 'Indianapolis, IN',
#   'lon': -86.1581,
#   'name': 'hhgregg',
#   'state': 'IN'},
#  914: {'city': 'Atlanta',
#   'industry': 'Oil and Gas Equipment, Services',
#   'lat': 33.749,
#   'location': 'Atlanta, GA',
#   'lon': -84.38799999999999,
#   'name': 'RPC',
#   'state': 'GA'},
#  915: {'city': 'Richmond',
#   'industry': 'Chemicals',
#   'lat': 37.5407,
#   'location': 'Richmond, VA',
#   'lon': -77.436,
#   'name': 'NewMarket',
#   'state': 'VA'},
#  916: {'city': 'Herndon',
#   'industry': 'Wholesalers: Diversified',
#   'lat': 38.9696,
#   'location': 'Herndon, VA',
#   'lon': -77.3861,
#   'name': 'Beacon Roofing Supply',
#   'state': 'VA'},
#  917: {'city': 'Irvine',
#   'industry': 'Medical Products and Equipment',
#   'lat': 33.6839,
#   'location': 'Irvine, CA',
#   'lon': -117.795,
#   'name': 'Edwards Lifesciences',
#   'state': 'CA'},
#  918: {'city': 'San Juan',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 18.4663,
#   'location': 'San Juan, PR',
#   'lon': -66.1057,
#   'name': 'Triple-S Management',
#   'state': 'PR'},
#  919: {'city': 'Honolulu',
#   'industry': 'Airlines',
#   'lat': 21.3069,
#   'location': 'Honolulu, HI',
#   'lon': -157.858,
#   'name': 'Hawaiian Holdings',
#   'state': 'HI'},
#  920: {'city': 'Princeton',
#   'industry': 'Financial Data Services',
#   'lat': 40.3573,
#   'location': 'Princeton, NJ',
#   'lon': -74.6672,
#   'name': 'Heartland Payment Systems',
#   'state': 'NJ'},
#  921: {'city': 'St. Louis',
#   'industry': 'Electronics, Electrical Equip.',
#   'lat': 38.626999999999995,
#   'location': 'St. Louis, MO',
#   'lon': -90.1994,
#   'name': 'Belden',
#   'state': 'MO'},
#  922: {'city': 'Tulsa',
#   'industry': 'Pipelines',
#   'lat': 36.154,
#   'location': 'Tulsa, OK',
#   'lon': -95.9928,
#   'name': 'Magellan Midstream Partners',
#   'state': 'OK'},
#  923: {'city': 'Bellevue',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 47.6104,
#   'location': 'Bellevue, WA',
#   'lon': -122.20100000000001,
#   'name': 'Outerwall',
#   'state': 'WA'},
#  924: {'city': 'Northbrook',
#   'industry': 'Packaging, Containers',
#   'lat': 42.1275,
#   'location': 'Northbrook, IL',
#   'lon': -87.829,
#   'name': 'KapStone Paper & Packaging',
#   'state': 'IL'},
#  925: {'city': 'Tulsa',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 36.154,
#   'location': 'Tulsa, OK',
#   'lon': -95.9928,
#   'name': 'Alliance Holdings',
#   'state': 'OK'},
#  926: {'city': 'Woburn',
#   'industry': 'Semiconductors and Other Electronic Components',
#   'lat': 42.4793,
#   'location': 'Woburn, MA',
#   'lon': -71.1523,
#   'name': 'Skyworks Solutions',
#   'state': 'MA'},
#  927: {'city': 'Hanover',
#   'industry': 'Network and Other Communications Equipment',
#   'lat': 39.19,
#   'location': 'Hanover, MD',
#   'lon': -76.723,
#   'name': 'Ciena',
#   'state': 'MD'},
#  928: {'city': 'Watsonville',
#   'industry': 'Engineering, Construction',
#   'lat': 36.9102,
#   'location': 'Watsonville, CA',
#   'lon': -121.757,
#   'name': 'Granite Construction',
#   'state': 'CA'},
#  929: {'city': 'Pittsburgh',
#   'industry': 'Education',
#   'lat': 40.4406,
#   'location': 'Pittsburgh, PA',
#   'lon': -79.9959,
#   'name': 'Education Management',
#   'state': 'PA'},
#  930: {'city': 'Elmsford',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 41.0551,
#   'location': 'Elmsford, NY',
#   'lon': -73.8201,
#   'name': 'Party City Holdings',
#   'state': 'NY'},
#  931: {'city': 'Irvine',
#   'industry': 'Real estate',
#   'lat': 33.6839,
#   'location': 'Irvine, CA',
#   'lon': -117.795,
#   'name': 'HCP',
#   'state': 'CA'},
#  932: {'city': 'Waltham',
#   'industry': 'Health Care: Pharmacy and Other Services',
#   'lat': 42.3765,
#   'location': 'Waltham, MA',
#   'lon': -71.2356,
#   'name': 'Parexel International',
#   'state': 'MA'},
#  933: {'city': 'McLean',
#   'industry': 'Aerospace and Defense',
#   'lat': 38.9339,
#   'location': 'McLean, VA',
#   'lon': -77.1773,
#   'name': 'Delta Tucker Holdings',
#   'state': 'VA'},
#  934: {'city': 'Las Vegas',
#   'industry': 'Hotels, Casinos, Resorts',
#   'lat': 36.1699,
#   'location': 'Las Vegas, NV',
#   'lon': -115.14,
#   'name': 'Pinnacle Entertainment',
#   'state': 'NV'},
#  935: {'city': 'St. Louis',
#   'industry': 'Securities',
#   'lat': 38.626999999999995,
#   'location': 'St. Louis, MO',
#   'lon': -90.1994,
#   'name': 'Stifel Financial',
#   'state': 'MO'},
#  936: {'city': 'Covington',
#   'industry': 'Wholesalers: Diversified',
#   'lat': 30.4755,
#   'location': 'Covington, LA',
#   'lon': -90.1009,
#   'name': 'Pool',
#   'state': 'LA'},
#  937: {'city': 'Clayton',
#   'industry': 'Chemicals',
#   'lat': 38.6426,
#   'location': 'Clayton, MO',
#   'lon': -90.3237,
#   'name': 'Olin',
#   'state': 'MO'},
#  938: {'city': 'New Haven',
#   'industry': 'Insurance: Life, Health (Mutual)',
#   'lat': 41.3083,
#   'location': 'New Haven, CT',
#   'lon': -72.9279,
#   'name': 'Knights of Columbus',
#   'state': 'CT'},
#  939: {'city': 'Waltham',
#   'industry': 'Scientific,Photographic and Control Equipment',
#   'lat': 42.3765,
#   'location': 'Waltham, MA',
#   'lon': -71.2356,
#   'name': 'PerkinElmer',
#   'state': 'MA'},
#  940: {'city': 'Cheshire',
#   'industry': 'Pharmaceuticals',
#   'lat': 41.5084,
#   'location': 'Cheshire, CT',
#   'lon': -72.9106,
#   'name': 'Alexion Pharmaceuticals',
#   'state': 'CT'},
#  941: {'city': 'Englewood',
#   'industry': 'Financial Data Services',
#   'lat': 39.6478,
#   'location': 'Englewood, CO',
#   'lon': -104.988,
#   'name': 'IHS',
#   'state': 'CO'},
#  942: {'city': 'Houston',
#   'industry': 'Oil and Gas Equipment, Services',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Oil States International',
#   'state': 'TX'},
#  943: {'city': 'Muscatine',
#   'industry': 'Home Equipment, Furnishings',
#   'lat': 41.4245,
#   'location': 'Muscatine, IA',
#   'lon': -91.0432,
#   'name': 'HNI',
#   'state': 'IA'},
#  944: {'city': 'Mountain View',
#   'industry': 'Internet Services and Retailing',
#   'lat': 37.3861,
#   'location': 'Mountain View, CA',
#   'lon': -122.084,
#   'name': 'LinkedIn',
#   'state': 'CA'},
#  945: {'city': 'Flint',
#   'industry': 'Food and Drug Stores',
#   'lat': 43.0125,
#   'location': 'Flint, MI',
#   'lon': -83.6875,
#   'name': 'Diplomat Pharmacy',
#   'state': 'MI'},
#  946: {'city': 'San Jose',
#   'industry': 'Network and Other Communications Equipment',
#   'lat': 37.3382,
#   'location': 'San Jose, CA',
#   'lon': -121.88600000000001,
#   'name': 'Brocade Communications Systems',
#   'state': 'CA'},
#  947: {'city': 'Lake Oswego',
#   'industry': 'Transportation Equipment',
#   'lat': 45.4207,
#   'location': 'Lake Oswego, OR',
#   'lon': -122.671,
#   'name': 'Greenbrier Cos.',
#   'state': 'OR'},
#  948: {'city': 'New York',
#   'industry': 'Entertainment',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'AMC Networks',
#   'state': 'NY'},
#  949: {'city': 'Chicago',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 41.8781,
#   'location': 'Chicago, IL',
#   'lon': -87.6298,
#   'name': 'Kemper',
#   'state': 'IL'},
#  950: {'city': 'Atlanta',
#   'industry': 'Diversified Financials',
#   'lat': 33.749,
#   'location': 'Atlanta, GA',
#   'lon': -84.38799999999999,
#   'name': 'Ocwen Financial',
#   'state': 'GA'},
#  951: {'city': 'Glendale',
#   'industry': 'zMiscellaneous',
#   'lat': 34.1425,
#   'location': 'Glendale, CA',
#   'lon': -118.255,
#   'name': 'Public Storage',
#   'state': 'CA'},
#  952: {'city': 'San Leandro',
#   'industry': 'Diversified Outsourcing Services',
#   'lat': 37.7249,
#   'location': 'San Leandro, CA',
#   'lon': -122.156,
#   'name': 'TriNet Group',
#   'state': 'CA'},
#  953: {'city': 'Philadelphia',
#   'industry': 'Chemicals',
#   'lat': 39.9526,
#   'location': 'Philadelphia, PA',
#   'lon': -75.1652,
#   'name': 'Chemtura',
#   'state': 'PA'},
#  954: {'city': 'Bellevue',
#   'industry': 'Insurance: Life, Health (stock)',
#   'lat': 47.6104,
#   'location': 'Bellevue, WA',
#   'lon': -122.20100000000001,
#   'name': 'Symetra Financial',
#   'state': 'WA'},
#  955: {'city': 'Livonia',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 42.3684,
#   'location': 'Livonia, MI',
#   'lon': -83.3527,
#   'name': 'Tower International',
#   'state': 'MI'},
#  956: {'city': 'Scottsdale',
#   'industry': 'Homebuilders',
#   'lat': 33.4942,
#   'location': 'Scottsdale, AZ',
#   'lon': -111.926,
#   'name': 'Meritage Homes',
#   'state': 'AZ'},
#  957: {'city': 'Denver',
#   'industry': 'Pipelines',
#   'lat': 39.7392,
#   'location': 'Denver, CO',
#   'lon': -104.99,
#   'name': 'MarkWest Energy Partners',
#   'state': 'CO'},
#  958: {'city': 'Hercules',
#   'industry': 'Medical Products and Equipment',
#   'lat': 38.0171,
#   'location': 'Hercules, CA',
#   'lon': -122.289,
#   'name': 'Bio-Rad Laboratories',
#   'state': 'CA'},
#  959: {'city': 'Tacoma',
#   'industry': 'Temporary Help',
#   'lat': 47.2529,
#   'location': 'Tacoma, WA',
#   'lon': -122.444,
#   'name': 'TrueBlue',
#   'state': 'WA'},
#  960: {'city': 'Houston',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Cabot Oil & Gas',
#   'state': 'TX'},
#  961: {'city': 'Wyomissing',
#   'industry': 'Metals',
#   'lat': 40.3295,
#   'location': 'Wyomissing, PA',
#   'lon': -75.9652,
#   'name': 'Carpenter Technology',
#   'state': 'PA'},
#  962: {'city': 'Bloomington',
#   'industry': 'Construction and Farm Machinery',
#   'lat': 44.8408,
#   'location': 'Bloomington, MN',
#   'lon': -93.2983,
#   'name': 'Toro',
#   'state': 'MN'},
#  963: {'city': 'West Des Moines',
#   'industry': 'Insurance: Life, Health (stock)',
#   'lat': 41.5772,
#   'location': 'West Des Moines, IA',
#   'lon': -93.7113,
#   'name': 'American Equity Investment Life Holding',
#   'state': 'IA'},
#  964: {'city': 'Columbus',
#   'industry': 'Specialty Retailers: Apparel',
#   'lat': 39.9612,
#   'location': 'Columbus, OH',
#   'lon': -82.9988,
#   'name': 'Express',
#   'state': 'OH'},
#  965: {'city': 'Rochester',
#   'industry': 'Scientific,Photographic and Control Equipment',
#   'lat': 43.161,
#   'location': 'Rochester, NY',
#   'lon': -77.6109,
#   'name': 'Eastman Kodak',
#   'state': 'NY'},
#  966: {'city': 'Lake Success',
#   'industry': 'Food Consumer Products',
#   'lat': 40.7707,
#   'location': 'Lake Success, NY',
#   'lon': -73.7176,
#   'name': 'Hain Celestial Group',
#   'state': 'NY'},
#  967: {'city': 'Coppell',
#   'industry': 'Diversified Financials',
#   'lat': 32.9546,
#   'location': 'Coppell, TX',
#   'lon': -97.015,
#   'name': 'Nationstar Mortgage Holdings',
#   'state': 'TX'},
#  968: {'city': 'Lake Forest',
#   'industry': 'Industrial Machinery',
#   'lat': 42.2586,
#   'location': 'Lake Forest, IL',
#   'lon': -87.8406,
#   'name': 'IDEX',
#   'state': 'IL'},
#  969: {'city': 'Hato Rey',
#   'industry': 'Commercial Banks',
#   'lat': 18.4294,
#   'location': 'Hato Rey, PR',
#   'lon': -66.0602,
#   'name': 'Popular',
#   'state': 'PR'},
#  970: {'city': 'Omaha',
#   'industry': 'Trucking, Truck Leasing',
#   'lat': 41.2524,
#   'location': 'Omaha, NE',
#   'lon': -95.99799999999999,
#   'name': 'Werner Enterprises',
#   'state': 'NE'},
#  971: {'city': 'Bellevue',
#   'industry': 'Aerospace and Defense',
#   'lat': 47.6104,
#   'location': 'Bellevue, WA',
#   'lon': -122.20100000000001,
#   'name': 'Esterline Technologies',
#   'state': 'WA'},
#  972: {'city': 'Sunnyvale',
#   'industry': 'Medical Products and Equipment',
#   'lat': 37.3688,
#   'location': 'Sunnyvale, CA',
#   'lon': -122.036,
#   'name': 'Intuitive Surgical',
#   'state': 'CA'},
#  973: {'city': 'Indianaoplis',
#   'industry': 'Motor Vehicles and Parts',
#   'lat': 39.7684,
#   'location': 'Indianaoplis, IN',
#   'lon': -86.1581,
#   'name': 'Allison Transmission Holdings',
#   'state': 'IN'},
#  974: {'city': 'Tulsa',
#   'industry': 'Pipelines',
#   'lat': 36.154,
#   'location': 'Tulsa, OK',
#   'lon': -95.9928,
#   'name': 'SemGroup',
#   'state': 'OK'},
#  975: {'city': 'Las Vegas',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 36.1699,
#   'location': 'Las Vegas, NV',
#   'lon': -115.14,
#   'name': 'Southwest Gas',
#   'state': 'NV'},
#  976: {'city': 'New York',
#   'industry': 'Apparel',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'G-III Apparel Group',
#   'state': 'NY'},
#  977: {'city': 'Williamsville',
#   'industry': 'Utilities: Gas and Electric',
#   'lat': 42.9639,
#   'location': 'Williamsville, NY',
#   'lon': -78.7378,
#   'name': 'National Fuel Gas',
#   'state': 'NY'},
#  978: {'city': 'St. Paul',
#   'industry': 'Chemicals',
#   'lat': 44.9537,
#   'location': 'St. Paul, MN',
#   'lon': -93.09,
#   'name': 'H.B. Fuller',
#   'state': 'MN'},
#  979: {'city': 'Horsham',
#   'industry': 'Insurance: Life, Health (stock)',
#   'lat': 40.1784,
#   'location': 'Horsham, PA',
#   'lon': -75.1285,
#   'name': 'Penn Mutual Life Insurance',
#   'state': 'PA'},
#  980: {'city': 'New York',
#   'industry': 'Securities',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'RCS Capital',
#   'state': 'NY'},
#  981: {'city': 'Portland',
#   'industry': 'Apparel',
#   'lat': 45.5231,
#   'location': 'Portland, OR',
#   'lon': -122.676,
#   'name': 'Columbia Sportswear',
#   'state': 'OR'},
#  982: {'city': 'Lincoln',
#   'industry': 'Insurance: Property and Casualty (Mutual)',
#   'lat': 41.911,
#   'location': 'Lincoln, RI',
#   'lon': -71.4418,
#   'name': 'Amica Mutual Insurance',
#   'state': 'RI'},
#  983: {'city': 'Dallas',
#   'industry': 'Engineering, Construction',
#   'lat': 32.7767,
#   'location': 'Dallas, TX',
#   'lon': -96.79700000000001,
#   'name': 'Primoris Services',
#   'state': 'TX'},
#  984: {'city': 'Birmingham',
#   'industry': 'Mining, Crude-Oil Production',
#   'lat': 33.5207,
#   'location': 'Birmingham, AL',
#   'lon': -86.8025,
#   'name': 'Energen',
#   'state': 'AL'},
#  985: {'city': 'Milwaukee',
#   'industry': 'Industrial Machinery',
#   'lat': 43.0389,
#   'location': 'Milwaukee, WI',
#   'lon': -87.9065,
#   'name': 'Rexnord',
#   'state': 'WI'},
#  986: {'city': 'Oklahoma City',
#   'industry': 'Oil and Gas Equipment, Services',
#   'lat': 35.4676,
#   'location': 'Oklahoma City, OK',
#   'lon': -97.5164,
#   'name': 'Seventy Seven Energy',
#   'state': 'OK'},
#  987: {'city': 'The Woodlands',
#   'industry': 'Waste Management',
#   'lat': 30.1658,
#   'location': 'The Woodlands, TX',
#   'lon': -95.4613,
#   'name': 'Waste Connections',
#   'state': 'TX'},
#  988: {'city': 'Philadelphia',
#   'industry': 'Specialty Retailers: Other',
#   'lat': 39.9526,
#   'location': 'Philadelphia, PA',
#   'lon': -75.1652,
#   'name': 'Pep Boys-Manny, Moe & Jack',
#   'state': 'PA'},
#  989: {'city': 'Camp Hill',
#   'industry': 'Metals',
#   'lat': 40.2398,
#   'location': 'Camp Hill, PA',
#   'lon': -76.92,
#   'name': 'Harsco',
#   'state': 'PA'},
#  990: {'city': 'Red Bank',
#   'industry': 'Homebuilders',
#   'lat': 40.3471,
#   'location': 'Red Bank, NJ',
#   'lon': -74.0643,
#   'name': 'Hovnanian Enterprises',
#   'state': 'NJ'},
#  991: {'city': 'Houston',
#   'industry': 'Oil and Gas Equipment, Services',
#   'lat': 29.7604,
#   'location': 'Houston, TX',
#   'lon': -95.3698,
#   'name': 'Willbros Group',
#   'state': 'TX'},
#  992: {'city': 'Dublin',
#   'industry': 'Food Services',
#   'lat': 40.0992,
#   'location': 'Dublin, OH',
#   'lon': -83.1141,
#   'name': "Wendy's",
#   'state': 'OH'},
#  993: {'city': 'Las Vegas',
#   'industry': 'Industrial Machinery',
#   'lat': 36.1699,
#   'location': 'Las Vegas, NV',
#   'lon': -115.14,
#   'name': 'International Game Technology',
#   'state': 'NV'},
#  994: {'city': 'Mountain View',
#   'industry': 'Computer Software',
#   'lat': 37.3861,
#   'location': 'Mountain View, CA',
#   'lon': -122.084,
#   'name': 'Synopsys',
#   'state': 'CA'},
#  995: {'city': 'White Plains',
#   'industry': 'Health Care: Insurance and Managed Care',
#   'lat': 41.034,
#   'location': 'White Plains, NY',
#   'lon': -73.7629,
#   'name': 'Universal American',
#   'state': 'NY'},
#  996: {'city': 'Wood Dale',
#   'industry': 'Aerospace and Defense',
#   'lat': 41.9634,
#   'location': 'Wood Dale, IL',
#   'lon': -87.979,
#   'name': 'AAR',
#   'state': 'IL'},
#  997: {'city': 'Branchville',
#   'industry': 'Insurance: Property and Casualty (Stock)',
#   'lat': 41.1465,
#   'location': 'Branchville, NJ',
#   'lon': -74.7524,
#   'name': 'Selective Insurance Group',
#   'state': 'NJ'},
#  998: {'city': 'Stamford',
#   'industry': 'Information Technology Services',
#   'lat': 41.0534,
#   'location': 'Stamford, CT',
#   'lon': -73.5387,
#   'name': 'Gartner',
#   'state': 'CT'},
#  999: {'city': 'New York',
#   'industry': 'Securities',
#   'lat': 40.7128,
#   'location': 'New York, NY',
#   'lon': -74.0059,
#   'name': 'E*Trade Financial',
#   'state': 'NY'}}

# %% [markdown]
# ## GET GLASSDOOR DATA

# %%
companies = []
extra = ["Jane Street", "Citadel", "Optiver", "Squarespace", "Wolverine Trading", "DRW", \
          "IMC Financial", "D.E.Shaw Research", "D.E.Shaw Investment" "Old Mission Capital", "Tower Research", "Two Sigma", \
          "Hudson River Trading", "Ellington Financial", "Town Square Trading", "Virtu Financial", "Vatic Labs", "Rubrik", \
         "Nauto", "Quora, Inc.", "Snapchat", "Palantir Technologies", "Addepar", "Susquehanna International Group", "Bessemer Venture", "Sequoia Capital", "KPCB", "Accel Partners", \
         "YCombinator", "8VC", "Asana", "Ctrl-labs", "Stripe"]

# %%
for q in extra:
    # authentication information & other request parameters
    params_gd = OrderedDict({
        "v": "1",
        "format": "json",
        "t.p": "204455",
        "t.k": "cbcOhZMtUHK",
        "action": "employers",
        "employerID": "11111",
        # programmatically get the IP of the machine
        "userip": '65.112.10.26',
        "useragent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.81 Safari/537.36",
        "q": q
    })

    # construct the URL from parameters
    basepath_gd = 'http://api.glassdoor.com/api/api.htm'

    # request the API
    response_gd = requests.get(basepath_gd,
                               params=params_gd,
                               headers={
                                   "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.81 Safari/537.36"
                               })
    # check the response code (should be 200)  & the content

    dat = json.loads(response_gd.content)
    companies += dat['response']['employers']

# %%
len(companies)
# Out:
# 73

# %%
list(map(lambda x: x['name'], companies))
# Out:
# ['Jane Street',
#  'Jane Street Entertainment',
#  'Citadel',
#  'Citadel',
#  'Citadel Federal Credit Union',
#  'The Citadel',
#  'Citadel Servicing',
#  'Citadel CPM',
#  'Citadel Information Management',
#  'Citadel Contact Systems',
#  'Citadel Security Services (Alarm Services)',
#  'Citadel Security and Investigations',
#  'Optiver',
#  'Optiv',
#  'Optival Health Solutions',
#  'Squarespace',
#  'Wolverine Trading',
#  'DRW',
#  'DRW Industrial',
#  'DRW-Verlag Weinbrenner',
#  'DRW CONSTRUCTION SERVICES',
#  'Vigilant',
#  'IMC Financial Markets',
#  'D. E. Shaw Research',
#  'Tower Research Capital LLC',
#  'Tower Cancer Research Foundation',
#  'Two Sigma',
#  'Hudson River Trading',
#  'Hudson River Trading Co.',
#  'Ellington Financial',
#  'Town Square Trading',
#  'Virtu Financial',
#  'Virtu Financial Tech Work',
#  'Vatic Labs',
#  'Rubrik',
#  'RUBRIK C',
#  'NAUTO',
#  'Quora, Inc.',
#  'Quora Consulting',
#  'Snap',
#  'Palantir Technologies',
#  'Addepar',
#  'Susquehanna International Group',
#  'Susquehanna Bancshares',
#  'Talen Energy',
#  'Susquehanna Health',
#  'Susquehanna University',
#  'Susquehanna Valley Nursing & Rehabilitation Center',
#  'Arden Courts of Susquehanna',
#  'Central Susquehanna Intermediate Unit',
#  'SVE Group',
#  'WGAL',
#  'BVP',
#  'Sequoia Capital',
#  'Kleiner Perkins Caufield & Byers',
#  'Accel Partners',
#  'Y Combinator',
#  '8VC',
#  'Asana',
#  'Asana Gruppe',
#  'Asana Health Products',
#  'Asana Rebel',
#  'Asana (Belgium)',
#  'Stripe',
#  'The ZigZag Stripe',
#  'Accent Stripe',
#  'Red Stripe',
#  'Stripe Entertainment Group',
#  'Stripe A Lot of America II',
#  'Butler Seal & Stripe',
#  'Stripe Communications',
#  'Straight Stripe Painting',
#  'Sunoco']

# %%
Counter(list(map(lambda x: x['sectorName'] if 'sectorName' in x else 'None', companies)))
# Out:
# Counter({'Accounting & Legal': 3,
#          'Arts, Entertainment & Recreation': 2,
#          'Biotech & Pharmaceuticals': 1,
#          'Business Services': 6,
#          'Construction, Repair & Maintenance': 3,
#          'Education': 5,
#          'Finance': 21,
#          'Government': 3,
#          'Health Care': 2,
#          'Information Technology': 17,
#          'Manufacturing': 5,
#          'Media': 2,
#          'None': 27,
#          'Oil, Gas, Energy & Utilities': 1,
#          'Retail': 2,
#          'Telecommunications': 1})

# %%
file = {
    "companies": companies
}
with open('js/companiesExtra.json', 'w') as outfile:
    json.dump(file, outfile)

# %%
dat
# Out:
# {'jsessionid': 'B5B10D87C7308F17127A397D72EEF884',
#  'response': {'attributionURL': 'http://www.glassdoor.com/Reviews/finance-reviews-SRCH_KE0,7.htm',
#   'currentPageNumber': 1,
#   'employers': [{'careerOpportunitiesRating': '5.0',
#     'ceo': {'name': 'Joe LaLeggia',
#      'numberOfRatings': 0,
#      'pctApprove': 0,
#      'pctDisapprove': 0,
#      'title': 'President'},
#     'compensationAndBenefitsRating': '4.0',
#     'cultureAndValuesRating': '4.0',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-Irwin-Commercial-Finance-Corporation-RVW2013214.htm',
#      'cons': 'Tempermental management, leadership out of its core depth (but quick to learn), unclear goals and multiple external drivers/stakeholders, required a great deal of flexibility',
#      'currentJob': False,
#      'headline': 'One of the first to fall',
#      'id': 2013214,
#      'jobTitle': 'Employee',
#      'location': 'Bellevue, WA',
#      'overall': 2,
#      'overallNumeric': 2,
#      'pros': 'Professional organization with focused leadership, good compensation for management and some staff- great product and diverse experience levels',
#      'reviewDateTime': '2012-10-03 08:42:35.68'},
#     'id': 18650,
#     'industry': '',
#     'isEEP': False,
#     'name': 'Irwin Commercial Finance Corporation',
#     'numberOfRatings': 1,
#     'overallRating': '2.0',
#     'ratingDescription': 'Dissatisfied',
#     'recommendToFriendRating': 0,
#     'seniorLeadershipRating': '3.0',
#     'squareLogo': '',
#     'website': 'www.irwincfequipment.com',
#     'workLifeBalanceRating': '2.0'},
#    {'careerOpportunitiesRating': '3.5',
#     'compensationAndBenefitsRating': '3.5',
#     'cultureAndValuesRating': '3.6',
#     'exactMatch': False,
#     'id': 890682,
#     'industry': 'Federal Agencies',
#     'industryId': 200056,
#     'industryName': 'Federal Agencies',
#     'isEEP': False,
#     'name': 'Ministry of Finance and Development Planning Liberia',
#     'numberOfRatings': 19,
#     'overallRating': '3.4',
#     'ratingDescription': 'OK',
#     'recommendToFriendRating': 75,
#     'sectorId': 10011,
#     'sectorName': 'Government',
#     'seniorLeadershipRating': '3.6',
#     'squareLogo': '',
#     'website': 'www.mfdp.gov.lr',
#     'workLifeBalanceRating': '3.7'},
#    {'careerOpportunitiesRating': '2.6',
#     'ceo': {'name': 'Tracy Young',
#      'numberOfRatings': 328,
#      'pctApprove': 44,
#      'pctDisapprove': 56,
#      'title': 'Chairman'},
#     'compensationAndBenefitsRating': '3.1',
#     'cultureAndValuesRating': '2.3',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-TMX-Finance-Family-of-Companies-RVW17139871.htm',
#      'cons': 'The hours are long, insurance to high, they should do more advertising on tv and radio, stop firing people and train them more',
#      'currentJob': True,
#      'headline': 'Tmx',
#      'id': 17139871,
#      'jobTitle': 'Employee',
#      'location': '',
#      'overall': 3,
#      'overallNumeric': 3,
#      'pros': 'The pay is good, the customer base is great,',
#      'reviewDateTime': '2017-10-03 05:32:06.417'},
#     'id': 617963,
#     'industry': 'Lending',
#     'industryId': 200054,
#     'industryName': 'Lending',
#     'isEEP': True,
#     'name': 'TMX Finance Family of Companies',
#     'numberOfRatings': 557,
#     'overallRating': '2.5',
#     'ratingDescription': 'OK',
#     'recommendToFriendRating': 37,
#     'sectorId': 10010,
#     'sectorName': 'Finance',
#     'seniorLeadershipRating': '2.2',
#     'squareLogo': 'https://media.glassdoor.com/sqll/617963/tmx-finance-family-of-companies-squarelogo-1483471817406.png',
#     'website': 'www.tmxfinancefamily.com',
#     'workLifeBalanceRating': '2.1'},
#    {'careerOpportunitiesRating': '3.0',
#     'ceo': {'image': {'height': 200,
#       'src': 'https://media.glassdoor.com/people/sqll/411618/springleaf-finance-jay-levine.png',
#       'width': 200},
#      'name': 'Jay Levine',
#      'numberOfRatings': 127,
#      'pctApprove': 70,
#      'pctDisapprove': 30,
#      'title': 'President & CEO'},
#     'compensationAndBenefitsRating': '3.2',
#     'cultureAndValuesRating': '2.9',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-Springleaf-Finance-RVW15989477.htm',
#      'cons': 'It was a temp position.',
#      'currentJob': False,
#      'headline': 'Best Manager and Team EVER!!!! (ONE MAIN FINANCIAL NOW)',
#      'id': 15989477,
#      'jobTitle': 'Office Assistant',
#      'jobTitleFromDb': 'Office Assistant',
#      'location': 'Brooksville, FL',
#      'overall': 5,
#      'overallNumeric': 5,
#      'pros': 'I had the opportunity to work for this company and I had the time of my life. I really appreciate all the help that I not only received from my co-workers; but also from my manager. She is exceptional, always willing to help and a very humble person. She definitely knows how to run the business and keep her employees happy.',
#      'reviewDateTime': '2017-07-20 08:13:27.323'},
#     'id': 411618,
#     'industry': 'Lending',
#     'industryId': 200054,
#     'industryName': 'Lending',
#     'isEEP': True,
#     'name': 'Springleaf Finance',
#     'numberOfRatings': 351,
#     'overallRating': '3.0',
#     'parentEmployer': {'id': 13598,
#      'isSunset': True,
#      'logo': {'mediumUrl': 'https://media.glassdoor.com/sqlm/13598/onemain-financial-squarelogo-1474901495451.png',
#       'normalUrl': 'https://media.glassdoor.com/sql/13598/onemain-financial-squarelogo-1474901495451.png',
#       'smallUrl': 'https://media.glassdoor.com/sqls/13598/onemain-financial-squarelogo-1474901495451.png'},
#      'name': 'OneMain',
#      'relationship': 'REBRANDEDAS',
#      'relationshipDate': '2015-11-17 00:00:00.0',
#      'sunsetMessage': 'For up to date information and jobs, please see the OneMain profile.'},
#     'ratingDescription': 'OK',
#     'recommendToFriendRating': 48,
#     'sectorId': 10010,
#     'sectorName': 'Finance',
#     'seniorLeadershipRating': '2.8',
#     'squareLogo': 'https://media.glassdoor.com/sqll/411618/springleaf-finance-squarelogo-1502910044504.png',
#     'website': 'www.onemainfinancial.com',
#     'workLifeBalanceRating': '2.9'},
#    {'careerOpportunitiesRating': '3.9',
#     'ceo': {'image': {'height': 200,
#       'src': 'https://media.glassdoor.com/people/sqll/779979/sofi-ceo1505915012942.png',
#       'width': 200},
#      'name': 'Tom Hutton',
#      'numberOfRatings': 2,
#      'pctApprove': 50,
#      'pctDisapprove': 50,
#      'title': 'Executive Chairman and Interim CEO'},
#     'compensationAndBenefitsRating': '4.2',
#     'cultureAndValuesRating': '3.6',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-SoFi-RVW17173551.htm',
#      'cons': 'Recent changes to C level.',
#      'currentJob': True,
#      'headline': 'I love working at SoFi',
#      'id': 17173551,
#      'jobTitle': 'Employee',
#      'location': '',
#      'overall': 5,
#      'overallNumeric': 5,
#      'pros': 'Amazing culture, incredibly smart people. Fast paced working environment.',
#      'reviewDateTime': '2017-10-04 16:02:38.92'},
#     'id': 779979,
#     'industry': 'Lending',
#     'industryId': 200054,
#     'industryName': 'Lending',
#     'isEEP': True,
#     'name': 'SoFi',
#     'numberOfRatings': 207,
#     'overallRating': '3.9',
#     'ratingDescription': 'Satisfied',
#     'recommendToFriendRating': 70,
#     'sectorId': 10010,
#     'sectorName': 'Finance',
#     'seniorLeadershipRating': '3.5',
#     'squareLogo': 'https://media.glassdoor.com/sqll/779979/sofi-squarelogo-1453356540292.png',
#     'website': 'www.sofi.com',
#     'workLifeBalanceRating': '3.4'},
#    {'careerOpportunitiesRating': '2.9',
#     'ceo': {'image': {'height': 200,
#       'src': 'https://media.glassdoor.com/people/sqll/6882/pinnacle-foods-ceo1464959059495.png',
#       'width': 200},
#      'name': 'Mark Clouse',
#      'numberOfRatings': 117,
#      'pctApprove': 83,
#      'pctDisapprove': 17,
#      'title': 'CEO'},
#     'compensationAndBenefitsRating': '3.4',
#     'cultureAndValuesRating': '2.9',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-Pinnacle-Foods-RVW17080596.htm',
#      'cons': 'No re-hire program, poor cafeteria',
#      'currentJob': False,
#      'headline': 'Intern',
#      'id': 17080596,
#      'jobTitle': 'Intern',
#      'jobTitleFromDb': 'Intern',
#      'location': 'Parsippany, NJ',
#      'overall': 5,
#      'overallNumeric': 5,
#      'pros': 'Interns are given real projects, not busy work. Very laid back environment with  opportunities for interns to interact with variety of functions',
#      'reviewDateTime': '2017-09-28 21:27:40.587'},
#     'id': 6882,
#     'industry': 'Food & Beverage Manufacturing',
#     'industryId': 200071,
#     'industryName': 'Food & Beverage Manufacturing',
#     'isEEP': True,
#     'name': 'Pinnacle Foods',
#     'numberOfRatings': 208,
#     'overallRating': '3.0',
#     'ratingDescription': 'OK',
#     'recommendToFriendRating': 55,
#     'sectorId': 10015,
#     'sectorName': 'Manufacturing',
#     'seniorLeadershipRating': '2.9',
#     'squareLogo': 'https://media.glassdoor.com/sqll/6882/pinnacle-foods-squarelogo-1407339159339.png',
#     'website': 'www.pinnaclefoods.com',
#     'workLifeBalanceRating': '2.6'},
#    {'careerOpportunitiesRating': '2.7',
#     'ceo': {'image': {'height': 200,
#       'src': 'https://media.glassdoor.com/people/sqll/556869/exeter-finance-ceo1479961130765.png',
#       'width': 200},
#      'name': 'Jason Grubb',
#      'numberOfRatings': 30,
#      'pctApprove': 64,
#      'pctDisapprove': 36,
#      'title': 'Chief Executive Officer'},
#     'compensationAndBenefitsRating': '3.1',
#     'cultureAndValuesRating': '2.7',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-Exeter-Finance-RVW17114138.htm',
#      'cons': 'Normal growing pains for a company its size',
#      'currentJob': True,
#      'headline': 'VP',
#      'id': 17114138,
#      'jobTitle': 'Employee',
#      'location': '',
#      'overall': 3,
#      'overallNumeric': 3,
#      'pros': 'Great people that care on improving services to the customer',
#      'reviewDateTime': '2017-10-01 16:29:33.83'},
#     'id': 556869,
#     'industry': 'Lending',
#     'industryId': 200054,
#     'industryName': 'Lending',
#     'isEEP': True,
#     'name': 'Exeter Finance',
#     'numberOfRatings': 160,
#     'overallRating': '2.8',
#     'ratingDescription': 'OK',
#     'recommendToFriendRating': 43,
#     'sectorId': 10010,
#     'sectorName': 'Finance',
#     'seniorLeadershipRating': '2.6',
#     'squareLogo': 'https://media.glassdoor.com/sqll/556869/exeter-finance-squarelogo-1489806000348.png',
#     'website': 'www.exeterfinance.com',
#     'workLifeBalanceRating': '3.0'},
#    {'careerOpportunitiesRating': '2.0',
#     'ceo': {'name': 'Tetsuo Iwamura',
#      'numberOfRatings': 48,
#      'pctApprove': 64,
#      'pctDisapprove': 36,
#      'title': 'President'},
#     'compensationAndBenefitsRating': '2.5',
#     'cultureAndValuesRating': '2.4',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-American-Honda-Finance-RVW17004838.htm',
#      'cons': 'No cons at this time',
#      'currentJob': False,
#      'headline': 'Honda is the power of dreams',
#      'id': 17004838,
#      'jobTitle': 'Senior Financial Analyst',
#      'jobTitleFromDb': 'Senior Financial Analyst',
#      'location': 'Torrance, CA',
#      'overall': 5,
#      'overallNumeric': 5,
#      'pros': 'Great benefits and supports the individual',
#      'reviewDateTime': '2017-09-25 08:31:38.017'},
#     'id': 17554,
#     'industry': 'Lending',
#     'industryId': 200054,
#     'industryName': 'Lending',
#     'isEEP': False,
#     'name': 'American Honda Finance',
#     'numberOfRatings': 152,
#     'overallRating': '2.5',
#     'ratingDescription': 'OK',
#     'recommendToFriendRating': 31,
#     'sectorId': 10010,
#     'sectorName': 'Finance',
#     'seniorLeadershipRating': '2.0',
#     'squareLogo': 'https://media.glassdoor.com/sqll/17554/american-honda-finance-squarelogo-1389132787457.png',
#     'website': 'www.hondafinancialservices.com',
#     'workLifeBalanceRating': '2.4'},
#    {'careerOpportunitiesRating': '2.8',
#     'ceo': {'image': {'height': 200,
#       'src': 'https://media.glassdoor.com/people/sqll/41320/defense-finance-and-accounting-service-ceo1491488131850.png',
#       'width': 200},
#      'name': 'Teresa McKay',
#      'numberOfRatings': 10,
#      'pctApprove': 62,
#      'pctDisapprove': 38,
#      'title': 'Director'},
#     'compensationAndBenefitsRating': '3.6',
#     'cultureAndValuesRating': '2.5',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-Defense-Finance-and-Accounting-Service-RVW17095601.htm',
#      'cons': "Culture is kind of bland. A lot of older people work here and a lot of things could be changed but it's difficult. Pay is not amazing. It'll do but I wish it was more.",
#      'currentJob': True,
#      'headline': 'Accounting Intern',
#      'id': 17095601,
#      'jobTitle': 'Accountant',
#      'jobTitleFromDb': 'Accountant',
#      'location': 'Lawrence, IN',
#      'overall': 4,
#      'overallNumeric': 4,
#      'pros': "Great benefits, extremely nice people, it seems like it's not too difficult to move up the ranks - just takes time, pay for grad school, and work/life balance is fantastic. No more than 40 hours a week unless unique situations and you get payed time and a half.",
#      'reviewDateTime': '2017-09-29 18:44:34.733'},
#     'id': 41320,
#     'industry': 'Federal Agencies',
#     'industryId': 200056,
#     'industryName': 'Federal Agencies',
#     'isEEP': False,
#     'name': 'Defense Finance and Accounting Service',
#     'numberOfRatings': 145,
#     'overallRating': '2.9',
#     'ratingDescription': 'OK',
#     'recommendToFriendRating': 50,
#     'sectorId': 10011,
#     'sectorName': 'Government',
#     'seniorLeadershipRating': '2.6',
#     'squareLogo': 'https://media.glassdoor.com/sqll/41320/us-defense-finance-and-accounting-service-squarelogo.png',
#     'website': 'www.dfas.mil',
#     'workLifeBalanceRating': '4.2'},
#    {'careerOpportunitiesRating': '3.1',
#     'ceo': {'image': {'height': 200,
#       'src': 'https://media.glassdoor.com/people/sqll/18874/ifc-jin-yong-cai.png',
#       'width': 200},
#      'name': 'Jin Yong Cai',
#      'numberOfRatings': 65,
#      'pctApprove': 71,
#      'pctDisapprove': 29,
#      'title': 'Executive Vice President & CEO'},
#     'compensationAndBenefitsRating': '3.5',
#     'cultureAndValuesRating': '3.7',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-IFC-RVW16838725.htm',
#      'cons': "Moves slowly and I don' t agree with the current strategy",
#      'currentJob': True,
#      'headline': 'Investment Analyst',
#      'id': 16838725,
#      'jobTitle': 'Employee',
#      'location': '',
#      'overall': 5,
#      'overallNumeric': 5,
#      'pros': 'People and culture are great. Work is interesting and fun',
#      'reviewDateTime': '2017-09-14 22:37:18.7'},
#     'id': 18874,
#     'industry': 'Investment Banking & Asset Management',
#     'industryId': 200053,
#     'industryName': 'Investment Banking & Asset Management',
#     'isEEP': False,
#     'name': 'IFC',
#     'numberOfRatings': 217,
#     'overallRating': '3.6',
#     'ratingDescription': 'Satisfied',
#     'recommendToFriendRating': 76,
#     'sectorId': 10010,
#     'sectorName': 'Finance',
#     'seniorLeadershipRating': '3.2',
#     'squareLogo': 'https://media.glassdoor.com/sqll/18874/ifc-squarelogo.png',
#     'website': 'www.ifc.org',
#     'workLifeBalanceRating': '3.7'}],
#   'totalNumberOfPages': 124,
#   'totalRecordCount': 1240},
#  'status': 'OK',
#  'success': True}

# %%
C = {}
names = {}

# %%
with open('js/companiesExtra.json') as data_file:    
    data = json.load(data_file)
    for company in data["companies"]:
        if not company["name"] in names:
            key = ''.join(random.choices(string.ascii_uppercase + string.ascii_lowercase + string.digits, k=12))
            C[key] = company
        names[company["name"]] = 1

# %%
len(C.keys())
# Out:
# 3558

# %%
with open('companiesFirebase.json', 'w') as outfile:
    json.dump(C, outfile)
